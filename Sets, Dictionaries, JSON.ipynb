# %%
import time

# %%
L = ['apple', 'orange', 'cherry', 'banana']

# %%
start = time.time()
'cherry' in L
print(time.time()-start)
# Out:
# 6.508827209472656e-05

# %%
flight_banned = {'Jane', 'Josh', 'John', 'Jess'}
flight_banned[0:2]s = {'Ali', 'Beth'} print(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 flight_banned = {'Jane', 'Josh', 'John', 'Jess'}
# ----> 2 flight_banned[0:2]
#
# TypeError: 'set' object is not subscriptable

# %%
s = {'Ali', 'Beth'} 
print(s)
# Out:
# {'Ali', 'Beth'}

# %%
print(s)
# Out:
# {'Ali', 'Beth'}

# %%
person = ['Ali', 'Bella', 'Rose', 'Sam'] 
grade = ['A+', 'A+', 'A', 'B+']

# %%
grades = dict(zip(person, grade))

# %%
for (person, grade) in grades.items():
    print(person + "'s grade is " + grade + '.')
# Out:
# Ali's grade is A+.
# Bella's grade is A+.
# Rose's grade is A.
# Sam's grade is B+.

# %%
for person, grade in grades.items():
    print(person + "'s grade is " + grade + '.')
# Out:
# Ali's grade is A+.
# Bella's grade is A+.
# Rose's grade is A.
# Sam's grade is B+.

# %%
def word_freq(sentence):
    words_list = sentence.split() 
    freq = {} 
    for word in words_list:
        if word in freq:
            freq[word] += 1
        else:
            freq[word] = 1
    return freq

# %%
sci_fi_books = {
"Dune": {
"Author": "Frank Herbert", "Published Year": 1965, "Main Themes": ["Politics", "Religion", "Ecology"], "Character Protagonist": "Paul Atreides" },
"Neuromancer": {
"Author": "William Gibson", "Published Year": 1984, "Main Themes": ["Cybernetics", "Artificial Intelligence", "Hacker Culture"], "Character Protagonist": "Case" },
"Foundation": {
"Author": "Isaac Asimov", "Published Year": 1951, "Main Themes": ["Collapse and Renewal", "Psychohistory", "Politics"], "Character Protagonist": "Hari Seldon" }
}

# %%
import pprint
pp = pprint.PrettyPrinter(0)
pp.pprint(sci_fi_books)
# Out:
# {'Dune': {'Author': 'Frank Herbert',
#         'Character Protagonist': 'Paul Atreides',
#         'Main Themes': ['Politics', 'Religion', 'Ecology'],
#         'Published Year': 1965},
# 'Foundation': {'Author': 'Isaac Asimov',
#               'Character Protagonist': 'Hari Seldon',
#               'Main Themes': ['Collapse and Renewal',
#                              'Psychohistory',
#                              'Politics'],
#               'Published Year': 1951},
# 'Neuromancer': {'Author': 'William Gibson',
#                'Character Protagonist': 'Case',
#                'Main Themes': ['Cybernetics',
#                               'Artificial Intelligence',
#                               'Hacker Culture'],
#                'Published Year': 1984}}

# %%
print(sci_fi_books['Dune']['Main Themes'][-1])
# Out:
# Ecology

# %%
test = [1,2,{'test':3}]

# %%
countries = ['USA', 'Canada', 'Mexico', 'Japan'] 
capitals = ['Washington, D.C.', 'Ottawa', 'Mexico City', 'ToKyo']
capital_dict = {} 
for i in range(len(countries)):
    capital_dict[countries[i]] = capitals[i]
capital_dict
# Out:
# {'USA': 'Washington, D.C.',
#  'Canada': 'Ottawa',
#  'Mexico': 'Mexico City',
#  'Japan': 'ToKyo'}

# %%
capital_dict = {zip(countries,capitals)}

# %%
capital_dict = dict(zip(countries, capitals)) 
print(capital_dict)
# Out:
# {'USA': 'Washington, D.C.', 'Canada': 'Ottawa', 'Mexico': 'Mexico City', 'Japan': 'ToKyo'}

# %%
capital_dict = {key:value for key, value in zip(countries, capitals)} 
print(capital_dict)
# Out:
# {'USA': 'Washington, D.C.', 'Canada': 'Ottawa', 'Mexico': 'Mexico City', 'Japan': 'ToKyo'}

# %%
odd = {key:(key % 2 == 1) for key in range(6)} 
print(odd)
# Out:
# {0: False, 1: True, 2: False, 3: True, 4: False, 5: True}

# %%
# import json
# with open('RepAdamSmith.json', 'r') as file:
#     data = json.load(file)

import json

file_path = 'RepAdamSmith.json'

json_data = []
with open(file_path, 'r') as f:
    for line in f:
        json_data.append(json.loads(line))

# %%
json_data
# Out:
# [{'text': 'Today, the President offered an initial plan to reduce gun violence. See my statement on the proposals here. http://t.co/kl6zR1TQ',
#   'created_at': 'Wed Jan 16 23:13:29 +0000 2013',
#   '_id': {'$oid': '5390f64f0263fb57038e131b'},
#   'id_str': '291684630363521024',
#   'user': {'follow_request_sent': False,
#    'profile_use_background_image': True,
#    'geo_enabled': False,
#    'verified': True,
#    'profile_image_url_https': 'https://si0.twimg.com/profile_images/1554717159/Adam_Official_Photo_small_2009_normal.JPG',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'is_translator': False,
#    'id': 58928690,
#    'profile_text_color': '333333',
#    'followers_count': 5654,
#    'protected': False,
#    'location': "Washington's 9th District",
#    'default_profile_image': False,
#    'id_str': '58928690',
#    'utc_offset': -18000,
#    'statuses_count': 756,
# ...

# %%
kaist = {
'full_name': 'Korea Advanced Institute of Science and Technology', 'location': 'Daejeon', 'year_founded': 1971 }
type(kaist)
# Out:
# dict

# %%
with open('json_data_kaist.json', 'w') as file:
    json.dump(kaist, file, indent = 4)
