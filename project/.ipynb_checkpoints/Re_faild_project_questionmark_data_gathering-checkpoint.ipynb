# %% [markdown]
# # Purpose of this project
#
# * ## find a correlaion between the drama script and content completion rate

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# https://www.whats-on-netflix.com/news/are-completion-rates-key-to-netflix-cancelations/
# <img src="./image/1.PNG" width="700" />
# <img src="./image/3.PNG" width="700" />

# %% [markdown]
# ---
# ---
# ---

# %% [markdown]
# # Can we measure the completion rate through the script?

# %% [markdown]
# ## 1. Gather two script data
# * The Irregulars : the lowest completion rate in upper image
# * Squid Game : the highest completion rate in upper image > This is what I'm going to present

# %% [markdown]
# ## 2. Get dialogues without actions
# * dropout actions : measure the depth between the characters using network analysis, not mise en scene(in the scene)
# * make dataframe : make a dataframe with charector and dialogue

# %% [markdown]
# ## 3. Measure the depth of emotions
# * run a network analysis : Using the dataframe, do a network analysis with each of episode of two drama-The Irregulars and Squid Game
# * Compare the firues

# %% [markdown]
# ---
# ---
# ---

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('./data/Sec_epi.xlsx')

# %%
df.head()
# Out:
#   Time                                   Subtitle  \
# 0  11s  [4조 조원들의 힘겨운 신음] (미녀) 야, 어떻게 좀 해 봐, 이 씨발!
# 1  17s                     (상우) 다들 정신 차리고 내 말 들어!
# 2  19s                   내가 신호하면 딱 세 발만 앞으로 가는 거야
# 3  22s                              앞으로 가라고? 미쳤어!
# 4  25s                               저쪽을 넘어뜨려야 돼!
#
#                                          Translation  \
# 0                         Do something! God damn it!
# 1            Pull yourselves together and listen up!
# 2  When I give the sign,\njust take three steps f...
# 3                         Go forward? Are you crazy?
# 4                         We have to make them trip!
#
#                                      Transliteration
# 0  [ 4jo   jo-wondeul-ui   himgyeo-un   sin-eum ]...
# 1  ( sang-u )   dadeul   jeongsin   chaligo   nae...
# 2  naega   sinhohamyeon   ttag   se   balman   ap...
# 3                ap-eulo   galago ?   michyeoss-eo !
# 4        jeo-jjog-eul   neom-eo-tteulyeo-ya   dwae !

# %%
df['Transliteration'] = df['Transliteration'].str.replace(')', '(')
# df['Translation'].str.split('(', expand=True)[1].
# Out:
# /var/folders/ps/mmfjqxl52pb1b3b_0bbt37gr0000gn/T/ipykernel_23347/652581887.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Subtitle'] = df['Subtitle'].str.replace(')', '(')

# %%
df['Transliteration'] = df['Transliteration'].str.rjust(width=1)

# %%
df['Transliteration']  = df['Transliteration'].str.split('(', expand=True)[1]

# %%
df.head()
# Out:
#   Time Subtitle                                        Translation  \
# 0  11s       미녀                         Do something! God damn it!
# 1  17s       상우            Pull yourselves together and listen up!
# 2  19s     None  When I give the sign,\njust take three steps f...
# 3  22s     None                         Go forward? Are you crazy?
# 4  25s     None                         We have to make them trip!
#
#                                      Transliteration
# 0  [ 4jo   jo-wondeul-ui   himgyeo-un   sin-eum ]...
# 1  ( sang-u )   dadeul   jeongsin   chaligo   nae...
# 2  naega   sinhohamyeon   ttag   se   balman   ap...
# 3                ap-eulo   galago ?   michyeoss-eo !
# 4        jeo-jjog-eul   neom-eo-tteulyeo-ya   dwae !

# %%
df = df[['Time', 'Transliteration', 'Translation']]

# %%
df.columns = ['Time', 'Character', 'Translation']

# %%
df.head(20)
# Out:
#     Time Character                                        Translation
# 0    11s        미녀                         Do something! God damn it!
# 1    17s        상우            Pull yourselves together and listen up!
# 2    19s      None  When I give the sign,\njust take three steps f...
# 3    22s      None                         Go forward? Are you crazy?
# 4    25s      None                         We have to make them trip!
# 5    27s      None                                   That's bullshit!
# 6    28s      None                              Let's give it a shot!
# 7    30s        미녀                                 No, I can't do it!
# 8    31s        상우                          If you can't, you'll die!
# 9    33s      None                        On the count of three! One!
# 10   34s      None            On the count of three! One! Two! Three!
# 11   46s      None                                              Pull!
# 12   51s      None                                              Pull…
# 13  1:14      None                                              Pull!
# 14  1:22       남자1                                                No!
# 15  2:52        지영                                               Hey.
# 16  2:54      None                  Who are you praying to right now?
# 17  2:57      None                                            To God?
# 18  3:00      None           Do you think you're alive thanks to God?
# 19  3:09      None  You're still breathing\nand moving that tongue...

# %%
df['Time'] = df['Time'].str.replace('s', '')

# %%
df['Time_sec'] = [int(x[0])*60 + int(x[1]) if len(x) >1 else int(x[0]) for x in df['Time'].str.split(':')]

# %%
df['Time_diff'] = df['Time_sec'].diff()

# %%
df['Time_diff'] = df['Time_diff'].fillna(2)

# %%
import matplotlib.pyplot as plt

plt.hist(df['Time_diff'], bins = 300)

plt.show()

# %%
# df[df['Time_diff']>25]

q3 = df['Time_diff'].quantile(0.75) # df['국어'].quantile(0.75) 처럼 특정 열만 적용 가능
q1 = df['Time_diff'].quantile(0.25)

print(q1, q3)
# Out:
# 2.0 5.0

# %%
df.head(20)
# Out:
#     Time Character                                        Translation  \
# 0     11        미녀                         Do something! God damn it!
# 1     17        상우            Pull yourselves together and listen up!
# 2     19      None  When I give the sign,\njust take three steps f...
# 3     22      None                         Go forward? Are you crazy?
# 4     25      None                         We have to make them trip!
# 5     27      None                                   That's bullshit!
# 6     28      None                              Let's give it a shot!
# 7     30        미녀                                 No, I can't do it!
# 8     31        상우                          If you can't, you'll die!
# 9     33      None                        On the count of three! One!
# 10    34      None            On the count of three! One! Two! Three!
# 11    46      None                                              Pull!
# 12    51      None                                              Pull…
# 13  1:14      None                                              Pull!
# 14  1:22       남자1                                                No!
# 15  2:52        지영                                               Hey.
# 16  2:54      None                  Who are you praying to right now?
# 17  2:57      None                                            To God?
# 18  3:00      None           Do you think you're alive thanks to God?
# 19  3:09      None  You're still breathing\nand moving that tongue...
#
#     Time_sec  Time_diff
# 0         11        2.0
# 1         17        6.0
# 2         19        2.0
# 3         22        3.0
# 4         25        3.0
# 5         27        2.0
# 6         28        1.0
# 7         30        2.0
# 8         31        1.0
# 9         33        2.0
# 10        34        1.0
# 11        46       12.0
# 12        51        5.0
# 13        74       23.0
# 14        82        8.0
# 15       172       90.0
# 16       174        2.0
# 17       177        3.0
# 18       180        3.0
# 19       189        9.0

# %%
df['split_point'] = np.where((df['Time_diff'] > q3), 1, 0).cumsum()

# %%
df.head(20)
# Out:
#     Time Character                                        Translation  \
# 0     11        미녀                         Do something! God damn it!
# 1     17        상우            Pull yourselves together and listen up!
# 2     19      None  When I give the sign,\njust take three steps f...
# 3     22      None                         Go forward? Are you crazy?
# 4     25      None                         We have to make them trip!
# 5     27      None                                   That's bullshit!
# 6     28      None                              Let's give it a shot!
# 7     30        미녀                                 No, I can't do it!
# 8     31        상우                          If you can't, you'll die!
# 9     33      None                        On the count of three! One!
# 10    34      None            On the count of three! One! Two! Three!
# 11    46      None                                              Pull!
# 12    51      None                                              Pull…
# 13  1:14      None                                              Pull!
# 14  1:22       남자1                                                No!
# 15  2:52        지영                                               Hey.
# 16  2:54      None                  Who are you praying to right now?
# 17  2:57      None                                            To God?
# 18  3:00      None           Do you think you're alive thanks to God?
# 19  3:09      None  You're still breathing\nand moving that tongue...
#
#     Time_sec  Time_diff  split_point
# 0         11        2.0            0
# 1         17        6.0            1
# 2         19        2.0            1
# 3         22        3.0            1
# 4         25        3.0            1
# 5         27        2.0            1
# 6         28        1.0            1
# 7         30        2.0            1
# 8         31        1.0            1
# 9         33        2.0            1
# 10        34        1.0            1
# 11        46       12.0            2
# 12        51        5.0            2
# 13        74       23.0            3
# 14        82        8.0            4
# 15       172       90.0            5
# 16       174        2.0            5
# 17       177        3.0            5
# 18       180        3.0            5
# 19       189        9.0            6

# %%
df['Character'] = df['Character'].fillna('N/A')

# %%
# df.groupby(['split_point'], as_index=False).apply(lambda x: ', '.join(x['Character']))
df['Characters'] = df.groupby('split_point').apply(lambda x: ', '.join(x.Character))

# %%
df_character = df.groupby('split_point').apply(lambda x: ', '.join(x.Character)).to_frame().reset_index()

# %%
df_merge = pd.merge(df, df_character[['split_point', 0]], on = 'split_point').drop(columns ='Characters')

# %%
df_merge.rename(columns = {0 : 'Charaters'}, inplace=True)

# %%
df_merge['Charaters'] = df_merge['Charaters'].apply(lambda x : set(x.replace(' ', '').split(',')))

# %%
df_merge.Charaters.value_counts()
# Out:
# {N/A}                          71
# {상우, N/A, 미녀, 알리, 기훈}          34
# {병정1, N/A, 병기, 병정2}            34
# {N/A, 준호, 일꾼}                  26
# {병정1, N/A}                     23
# {N/A, 일남}                      21
# {병정1, 병기, N/A, 일꾼, 기훈, 병정2}    19
# {N/A, 일꾼}                      19
# {남자2, 상우, 새벽, N/A, 남자4}        17
# {N/A, 알리}                      16
# {기훈, N/A}                      16
# {상우, N/A, 기훈, 남자6, 덕수}         15
# {병정1, N/A, 일꾼}                 15
# {병정1, 병기, N/A, 준호, 병정2}        13
# {N/A, 남자2}                     10
# {N/A, 상우, 미녀}                  10
# {N/A, 미녀}                       9
# {N/A, 남자3, 덕수}                  9
# {N/A, 병정2}                      9
# {덕수, N/A}                       8
# {새벽, N/A, 지영}                   8
# {새벽, N/A}                       8
# {기훈, N/A, 새벽}                   7
# {대장, 관리자2, N/A}                 7
# {병정1, N/A, 일꾼, 병정2}             7
# {N/A, 일꾼, 병정2}                  6
# {N/A, 병기, 일꾼}                   6
# {기훈, N/A, 남자5}                  6
# {기훈, 병정3, N/A}                  4
# {대장, N/A}                       4
# {N/A, 지영}                       4
# {N/A, 병정3}                      4
# {남자6, N/A}                      3
# {대장, 관리자3, 관리자4}                3
# {병정1}                           3
# {일꾼}                            2
# {N/A, 남자5}                      2
# {병기}                            2
# {N/A, 준호}                       2
# {남자3, 병정4}                      2
# {관리자2, N/A}                     2
# {N/A, 남자3}                      2
# {남자6}                           1
# {대장}                            1
# {미녀}                            1
# {관리자1}                          1
# {남자7}                           1
# {상우}                            1
# {남자1}                           1
# {준호}                            1
# Name: Charaters, dtype: int64

# %%
from nltk import word_tokenize, pos_tag, ne_chunk

# %%
df_merge['Translation'][0]
# Out:
# 'Do something! God damn it!'

# %%
a = [pos_tag(word_tokenize(x)) for x in df_merge['Translation']]

# %%
[ne_chunk(x) for x in a]
# Out:
# [Tree('S', [('Do', 'VB'), ('something', 'NN'), ('!', '.'), ('God', 'NNP'), ('damn', 'VBZ'), ('it', 'PRP'), ('!', '.')]),
#  Tree('S', [Tree('GPE', [('Pull', 'NNP')]), ('yourselves', 'VBZ'), ('together', 'RB'), ('and', 'CC'), ('listen', 'VB'), ('up', 'RP'), ('!', '.')]),
#  Tree('S', [('When', 'WRB'), ('I', 'PRP'), ('give', 'VBP'), ('the', 'DT'), ('sign', 'NN'), (',', ','), ('just', 'RB'), ('take', 'VB'), ('three', 'CD'), ('steps', 'NNS'), ('forward', 'RB'), ('!', '.')]),
#  Tree('S', [('Go', 'VB'), ('forward', 'RB'), ('?', '.'), ('Are', 'NNP'), ('you', 'PRP'), ('crazy', 'JJ'), ('?', '.')]),
#  Tree('S', [('We', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('make', 'VB'), ('them', 'PRP'), ('trip', 'NN'), ('!', '.')]),
#  Tree('S', [('That', 'DT'), ("'s", 'VBZ'), ('bullshit', 'NN'), ('!', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'PRP'), ('give', 'VB'), ('it', 'PRP'), ('a', 'DT'), ('shot', 'NN'), ('!', '.')]),
#  Tree('S', [('No', 'DT'), (',', ','), ('I', 'PRP'), ('ca', 'MD'), ("n't", 'RB'), ('do', 'VB'), ('it', 'PRP'), ('!', '.')]),
#  Tree('S', [('If', 'IN'), ('you', 'PRP'), ('ca', 'MD'), ("n't", 'RB'), (',', ','), ('you', 'PRP'), ("'ll", 'MD'), ('die', 'VB'), ('!', '.')]),
#  Tree('S', [('On', 'IN'), ('the', 'DT'), ('count', 'NN'), ('of', 'IN'), ('three', 'CD'), ('!', '.'), ('One', 'CD'), ('!', '.')]),
#  Tree('S', [('On', 'IN'), ('the', 'DT'), ('count', 'NN'), ('of', 'IN'), ('three', 'CD'), ('!', '.'), ('One', 'CD'), ('!', '.'), ('Two', 'CD'), ('!', '.'), ('Three', 'CD'), ('!', '.')]),
#  Tree('S', [Tree('GPE', [('Pull', 'NN')]), ('!', '.')]),
#  Tree('S', [('Pull…', 'NN')]),
#  Tree('S', [Tree('GPE', [('Pull', 'NN')]), ('!', '.')]),
#  Tree('S', [('No', 'DT'), ('!', '.')]),
#  Tree('S', [('Hey', 'NNP'), ('.', '.')]),
#  Tree('S', [('Who', 'WP'), ('are', 'VBP'), ('you', 'PRP'), ('praying', 'VBG'), ('to', 'TO'), ('right', 'VB'), ('now', 'RB'), ('?', '.')]),
#  Tree('S', [('To', 'TO'), ('God', 'NNP'), ('?', '.')]),
#  Tree('S', [('Do', 'VBP'), ('you', 'PRP'), ('think', 'VB'), ('you', 'PRP'), ("'re", 'VBP'), ('alive', 'JJ'), ('thanks', 'NNS'), ('to', 'TO'), ('God', 'NNP'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ("'re", 'VBP'), ('still', 'RB'), ('breathing', 'VBG'), ('and', 'CC'), ('moving', 'VBG'), ('that', 'IN'), ('tongue', 'NN'), ('of', 'IN'), ('yours', 'NNS')]),
#  Tree('S', [('thanks', 'NNS'), ('to', 'TO'), ('that', 'DT'), ('old', 'JJ'), ('man', 'NN')]),
#  Tree('S', [('and', 'CC'), ('that', 'DT'), ('guy', 'NN'), ('over', 'IN'), ('there', 'EX'), ('who', 'WP'), ('pulled', 'VBD'), ('out', 'RP'), ('that', 'IN'), ('awesome', 'JJ'), ('trick', 'JJ'), ('last-minute', 'NN'), ('.', '.')]),
#  Tree('S', [('So', 'RB'), ('if', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('going', 'VBG'), ('to', 'TO'), ('thank', 'VB'), ('anyone', 'NN'), (',', ',')]),
#  Tree('S', [('thank', 'VB'), ('them', 'PRP'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('poor', 'JJ'), ('lost', 'VBN'), ('lamb', 'NN'), ('.', '.')]),
#  Tree('S', [('Ca', 'NNP'), ("n't", 'RB'), ('you', 'PRP'), ('hear', 'VBP'), ('the', 'DT'), ('cries', 'NNS'), ('of', 'IN'), ('those', 'DT'), ('who', 'WP'), ('were', 'VBD'), ('nailed', 'VBN'), ('to', 'TO'), ('the', 'DT'), ('cross', 'NN'), ('today', 'NN'), ('?', '.')]),
#  Tree('S', [('We', 'PRP'), ('lived', 'VBD'), ('to', 'TO'), ('see', 'VB'), ('another', 'DT'), ('day', 'NN'), ('thanks', 'NNS'), ('to', 'TO'), ('their', 'PRP$'), ('blood', 'NN'), ('and', 'CC'), ('sacrifice', 'NN'), ('.', '.')]),
#  Tree('S', [('On', 'IN'), ('behalf', 'NN'), ('of', 'IN'), ('all', 'DT'), ('us', 'PRP'), ('sinners', 'NNS'), (',', ',')]),
#  Tree('S', [('I', 'PRP'), ('am', 'VBP'), ('thanking', 'VBG'), ('the', 'DT'), Tree('ORGANIZATION', [('Lord', 'NNP')]), ('for', 'IN'), ('his', 'PRP$'), ('decision', 'NN'), ('and', 'CC'), ('their', 'PRP$'), ('sacrifice', 'NN'), (',', ',')]),
#  Tree('S', [('and', 'CC'), ('saying', 'VBG'), ('a', 'DT'), ('prayer', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Bullshit', 'NNP')]), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('killed', 'VBD'), ('them', 'PRP'), ('yourself', 'PRP'), ('.', '.')]),
#  Tree('S', [('So', 'IN'), ('we', 'PRP'), ('all', 'DT'), ('get', 'VBP'), ('to', 'TO'), ('go', 'VB'), ('to', 'TO'), ('heaven', 'RB'), ('if', 'IN'), ('we', 'PRP'), ('mumble', 'VBP'), ('a', 'DT'), ('few', 'JJ'), ('prayers', 'NNS'), ('?', '.')]),
#  Tree('S', [Tree('GPE', [('Shit', 'NNP')]), (',', ','), ('then', 'RB'), ('I', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('pray', 'VB'), ('too', 'RB'), ('.', '.')]),
#  Tree('S', [('Heavenly', 'RB'), Tree('PERSON', [('Father', 'NNP')]), (',', ','), ('we', 'PRP'), ('worked', 'VBD'), ('together', 'RB'), ('as', 'IN'), ('a', 'DT'), ('team', 'NN'), ('today', 'NN'), ('to', 'TO'), ('send', 'VB'), ('many', 'JJ'), ('people', 'NNS'), ('to', 'TO'), ('your', 'PRP$'), ('side', 'NN'), ('.', '.')]),
#  Tree('S', [('we', 'PRP'), ('worked', 'VBD'), ('together', 'RB'), ('as', 'IN'), ('a', 'DT'), ('team', 'NN'), ('today', 'NN'), ('to', 'TO'), ('send', 'VB'), ('many', 'JJ'), ('people', 'NNS'), ('to', 'TO'), ('your', 'PRP$'), ('side', 'NN'), ('.', '.')]),
#  Tree('S', [('Please', 'VB'), ('help', 'VB'), ('us', 'PRP'), ('send', 'VB'), ('more', 'JJR'), ('people', 'NNS'), ('to', 'TO'), ('your', 'PRP$'), ('side', 'NN'), ('from', 'IN'), ('now', 'RB'), ('on', 'IN'), ('--', ':')]),
#  Tree('S', [('Be', 'NNP'), ('quiet', 'JJ'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Me', 'NNP')]), ('?', '.')]),
#  Tree('S', [('Or', 'CC'), ('that', 'DT'), ('guy', 'NN'), ('?', '.')]),
#  Tree('S', [('Both', 'DT'), ('of', 'IN'), ('you', 'PRP'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ("'s", 'VBZ'), ('your', 'PRP$'), ('name', 'NN'), ('?', '.')]),
#  Tree('S', [('Why', 'WRB'), ('do', 'VBP'), ('you', 'PRP'), ('want', 'VB'), ('to', 'TO'), ('know', 'VB'), ('?', '.')]),
#  Tree('S', [('So', 'IN'), ('I', 'PRP'), ('can', 'MD'), ('call', 'VB'), ('you', 'PRP'), ('using', 'VBG'), ('your', 'PRP$'), ('name', 'NN'), ('.', '.')]),
#  Tree('S', [('Do', 'VBP'), ("n't", 'RB'), ('call', 'VB'), ('me', 'PRP'), ('then', 'RB'), ('.', '.')]),
#  Tree('S', [('Playing', 'VBG'), ('hard', 'JJ'), ('to', 'TO'), ('get', 'VB'), ('?', '.')]),
#  Tree('S', [('Do', 'VB'), ('me', 'PRP'), ('a', 'DT'), ('favor', 'NN'), ('.', '.')]),
#  Tree('S', [('Just', 'RB'), ('leave', 'VB'), ('me', 'PRP'), ('alone', 'RB'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ("'re", 'VBP'), ('the', 'DT'), ('one', 'NN'), ('who', 'WP'), ('talked', 'VBD'), ('to', 'TO'), ('me', 'PRP'), ('first', 'RB'), ('.', '.')]),
#  Tree('S', [('Did', 'NNP'), ('you', 'PRP'), ('see', 'VBP'), ('that', 'IN'), ('bald', 'NN'), ('guy', 'NN'), ('piss', 'VB'), ('his', 'PRP$'), ('pants', 'NNS'), ('?', '.')]),
#  Tree('S', [('After', 'IN'), ('that', 'DT'), (',', ','), ('all', 'PDT'), ('the', 'DT'), ('wusses', 'NNS'), ('behind', 'IN'), ('him', 'PRP'), ('kept…', 'VB')]),
#  Tree('S', [('He', 'PRP'), ("'s", 'VBZ'), ('not', 'RB'), ('breathing', 'JJ'), ('.', '.'), ('Go', 'VB'), ('get', 'VB'), ('the', 'DT'), ('doctor', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('seriously', 'RB'), ('thought', 'VBD'), ('we', 'PRP'), ('were', 'VBD'), ('all', 'DT'), ('going', 'VBG'), ('to', 'TO'), ('die', 'VB'), ('.', '.')]),
#  Tree('S', [('But', 'CC'), ('once', 'RB'), ('I', 'PRP'), ('laid', 'VBP'), ('back', 'RB'), (',', ','), ('I', 'PRP'), ('really', 'RB'), ('felt', 'VBD'), ('so', 'RB'), ('much', 'JJ'), ('stronger', 'JJR'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('What', 'WP'), ('is', 'VBZ'), ('this', 'DT'), ('?', '.'), ('This', 'DT'), ('works', 'VBZ'), ('?', '.'), ("''", "''")]),
#  Tree('S', [Tree('GPE', [('Sir', 'NNP')]), (',', ','), ('how', 'WRB'), ('did', 'VBD'), ('you', 'PRP'), ('come', 'VB'), ('up', 'RP'), ('with', 'IN'), ('that', 'DT'), ('?', '.')]),
#  Tree('S', [('When', 'WRB'), ('I', 'PRP'), ('was', 'VBD'), ('young', 'JJ'), (',', ','), ('I', 'PRP'), ('just', 'RB'), ('--', ':')]),
#  Tree('S', [('You', 'PRP'), ('copied', 'VBD'), ('that', 'IN'), ('from', 'IN'), ('a', 'DT'), ('movie', 'NN'), (',', ','), ('right', 'RB'), ('?', '.'), ('What', 'WP'), ("'s", 'VBZ'), ('that', 'DT'), ('movie', 'NN'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ('know', 'VBP'), (',', ','), ('the', 'DT'), ('one', 'NN'), ('that', 'WDT'), ('goes', 'VBZ'), ('like', 'IN'), ('this', 'DT'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('GPE', [('Matrix', 'NNP')]), ('.', '.')]),
#  Tree('S', [('So', 'RB'), (',', ','), ('you', 'PRP'), ('slacked', 'VBD'), ('off', 'RP'), ('at', 'IN'), ('work', 'NN'), ('and', 'CC'), ('just', 'RB'), ('watched', 'VBN'), ('movies', 'NNS'), ('in', 'IN'), Tree('GPE', [('Korea', 'NNP')]), ('?', '.')]),
#  Tree('S', [('And', 'CC'), ('you', 'PRP'), (',', ','), ('babe', "''"), ('.', '.')]),
#  Tree('S', [('``', '``'), ('Just', 'RB'), ('take', 'VB'), ('three', 'CD'), ('steps', 'NNS'), ('forward', 'RB'), ('!', '.'), ("''", "''")]),
#  Tree('S', [('I', 'PRP'), ('mean', 'VBP'), (',', ','), ('that', 'DT'), ('was', 'VBD'), ('way', 'NN'), ('too', 'RB'), ('cool', 'JJ'), ('.', '.')]),
#  Tree('S', [('How', 'WRB'), ('did', 'VBD'), ('you', 'PRP'), ('come', 'VB'), ('up', 'RP'), ('with', 'IN'), ('that', 'DT'), ('in', 'IN'), ('that', 'DT'), ('situation', 'NN'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ('said', 'VBD'), ('that', 'IN'), ('was', 'VBD'), ('bullshit', 'VBN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('did', 'VBD'), ('?', '.')]),
#  Tree('S', [('What', 'WP'), ('are', 'VBP'), ('you', 'PRP'), ('bullshitting', 'VBG'), ('about', 'IN'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ('were', 'VBD'), ('crying', 'VBG'), (',', ',')]),
#  Tree('S', [('``', '``'), ('Are', 'VBP'), ('you', 'PRP'), ('crazy', 'JJ'), ('?', '.'), ('That', 'DT'), ("'s", 'VBZ'), ('bullshit', 'NN'), ('!', '.'), ("''", "''")]),
#  Tree('S', [('That', 'DT'), ("'s", 'VBZ'), ('what', 'WP'), ('you', 'PRP'), ('said', 'VBD'), ('.', '.')]),
#  Tree('S', [('Hey', 'NN'), ('!', '.'), ('Which', 'JJ'), ('country', 'NN'), ('are', 'VBP'), ('you', 'PRP'), ('from', 'IN'), ('?', '.')]),
#  Tree('S', [('Do', 'VBP'), ('you', 'PRP'), ('even', 'RB'), ('have', 'VBP'), ('a', 'DT'), ('visa', 'NN'), ('?', '.'), ('You', 'PRP'), ("'re", 'VBP'), ('an', 'DT'), ('illegal', 'JJ'), ('alien', 'NN'), (',', ','), ('right', 'RB'), ('?', '.')]),
#  Tree('S', [Tree('GPE', [('Gosh', 'NNP')]), ('.', '.'), Tree('PERSON', [('Look', 'NNP')]), (',', ','), ('boys', 'VBZ'), ('.', '.')]),
#  Tree('S', [('Should', 'MD'), ('we', 'PRP'), ('really', 'RB'), ('let', 'VB'), ('this', 'DT'), ('strange', 'JJ'), ('foreign', 'JJ'), ('guy', 'NN'), ('stay', 'NN'), ('on', 'IN'), ('our', 'PRP$'), ('team', 'NN'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ('should', 'MD'), ('take', 'VB'), ('this', 'DT'), ('chance', 'NN'), ('to', 'TO'), ('sort', 'VB'), ('this', 'DT'), ('team', 'NN'), ('out', 'RB'), ('.', '.')]),
#  Tree('S', [('Who', 'WP'), ("'s", 'VBZ'), ('the', 'DT'), ('leader', 'NN'), ('here', 'RB'), ('?', '.')]),
#  Tree('S', [Tree('GPE', [('Cool', 'NNP')]), ('guy', 'NN'), (',', ','), ('are', 'VBP'), ('you', 'PRP'), ('the', 'DT'), ('leader', 'NN'), ('?', '.')]),
#  Tree('S', [('We', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('have', 'VB'), ('a', 'DT'), ('leader', 'NN'), ('.', '.'), ('We', 'PRP'), ("'re", 'VBP'), ('all', 'DT'), ('equal', 'JJ'), ('on', 'IN'), ('this', 'DT'), ('team', 'NN'), ('.', '.')]),
#  Tree('S', [('Even', 'RB'), ('better', 'RBR'), ('.', '.')]),
#  Tree('S', [('An', 'DT'), ('egalitarian', 'JJ'), ('society', 'NN'), ('!', '.')]),
#  Tree('S', [Tree('GPE', [('Shit', 'NNP')]), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), ('totally', 'RB'), ('different', 'JJ'), ('to', 'TO'), ('some', 'DT'), ('damn', 'NN'), ('thug', 'NN')]),
#  Tree('S', [Tree('GPE', [('Shit', 'NNP')]), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), ('totally', 'RB'), ('different', 'JJ'), ('to', 'TO'), ('some', 'DT'), ('damn', 'NN'), ('thug', 'NNS'), ('who', 'WP'), ('thinks', 'VBZ'), ('he', 'PRP'), ("'s", 'VBZ'), ('the', 'DT'), ('king', 'NN'), ('and', 'CC'), ('does', 'VBZ'), ('whatever', 'WDT'), ('he', 'PRP'), ('wants', 'VBZ'), ('.', '.')]),
#  Tree('S', [('who', 'WP'), ('thinks', 'VBZ'), ('he', 'PRP'), ("'s", 'VBZ'), ('the', 'DT'), ('king', 'NN'), ('and', 'CC'), ('does', 'VBZ'), ('whatever', 'WDT'), ('he', 'PRP'), ('wants', 'VBZ'), ('.', '.')]),
#  Tree('S', [('But', 'CC'), (',', ','), ('why', 'WRB'), ('did', 'VBD'), ('you', 'PRP'), ('get', 'VB'), ('kicked', 'VBN'), ('out', 'RP'), (',', ','), ('missus', 'NN'), ('?', '.')]),
#  Tree('S', [Tree('PERSON', [('Babe', 'NNP')]), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('not', 'RB'), ('a', 'DT'), ('missus', 'NN'), ('.', '.')]),
#  Tree('S', [('My', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), Tree('PERSON', [('Han', 'NNP'), ('Mi-nyeo', 'NNP')]), ('.', '.')]),
#  Tree('S', [('Just', 'RB'), ('call', 'VB'), ('me', 'PRP'), ('Mi-nyeo', 'NNP'), ('.', '.')]),
#  Tree('S', [('And', 'CC'), ('I', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('kicked', 'VBN'), ('out', 'RP'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('chose', 'VBD'), ('to', 'TO'), ('leave', 'VB'), ('the', 'DT'), ('team', 'NN'), ('.', '.')]),
#  Tree('S', [('Those', 'DT'), ('thugs', 'NNS'), ('and', 'CC'), ('I', 'PRP'), ('were', 'VBD'), ('on', 'IN'), ('completely', 'RB'), ('different', 'JJ'), ('levels', 'NNS'), ('.', '.')]),
#  Tree('S', [('They', 'PRP'), ('only', 'RB'), ('abandoned', 'VBD'), ('you', 'PRP'), ('and', 'CC'), ('then', 'RB'), ('picked', 'VBD'), ('the', 'DT'), ('big', 'JJ'), ('guys', 'NNS'), ('.', '.')]),
#  Tree('S', [('Right', 'RB'), ('before', 'IN'), ('the', 'DT'), ('game', 'NN'), ('at', 'IN'), ('that', 'DT'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('as', 'IN'), ('if', 'IN'), ('they', 'PRP'), ('knew', 'VBD'), ('what', 'WP'), ('game', 'NN'), ('was', 'VBD'), ('next', 'JJ'), ('.', '.')]),
#  Tree('S', [('Lights', 'NNS'), ('out', 'RP'), ('in', 'IN'), ('30', 'CD'), ('minutes', 'NNS'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Please', 'NNP')]), ('get', 'VB'), ('ready', 'JJ'), ('to', 'TO'), ('sleep', 'VB'), ('.', '.')]),
#  Tree('S', [('Another', 'DT'), ('fight', 'NN'), ('might', 'MD'), ('break', 'VB'), ('out', 'RP'), ('once', 'RB'), ('the', 'DT'), ('lights', 'NNS'), ('go', 'VBP'), ('out', 'RP'), ('.', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'POS'), ('prepare', 'JJ'), ('ourselves', 'NNS'), ('.', '.')]),
#  Tree('S', [('How', 'WRB'), ('so', 'RB'), ('?', '.')]),
#  Tree('S', [('We', 'PRP'), ('have', 'VBP'), ('these', 'DT'), ('women', 'NNS'), ('and', 'CC'), ('an', 'DT'), ('old', 'JJ'), ('man', 'NN'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ("'re", 'VBP'), ('the', 'DT'), ('weakest', 'JJS'), ('team', 'NN'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'PRP'), ('pick', 'VB'), ('a', 'DT'), ('weak', 'JJ'), ('team', 'NN'), ('and', 'CC'), ('attack', 'VB'), ('them', 'PRP'), ('first', 'RB'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), Tree('ORGANIZATION', [('Lord', 'NNP')]), ("'s", 'POS'), ('servant', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('vicious', 'JJ'), ('one', 'CD'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ("'re", 'VBP'), ('all', 'DT'), ('sinners', 'NNS'), ('already', 'RB'), ('.', '.')]),
#  Tree('S', [('Our', 'PRP$'), ('hands', 'NNS'), ('are', 'VBP'), ('drenched', 'VBN'), ('in', 'IN'), ('blood', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Offense', 'NN')]), ('is', 'VBZ'), ('the', 'DT'), ('best', 'JJS'), ('form', 'NN'), ('of', 'IN'), ('defense', 'NN'), ('.', '.'), ('Let', 'VB'), ("'s", 'POS'), ('attack', 'NN'), ('first', 'RB'), ('.', '.')]),
#  Tree('S', [('During', 'IN'), ('the', 'DT'), ('fight', 'NN'), ('last', 'JJ'), ('night', 'NN'), (',', ',')]),
#  Tree('S', [('do', 'VB'), ('you', 'PRP'), ('know', 'VB'), ('how', 'WRB'), ('the', 'DT'), ('man', 'NN'), ('in', 'IN'), ('front', 'NN'), ('of', 'IN'), ('me', 'PRP'), ('died', 'VBD'), ('?', '.')]),
#  Tree('S', [('Someone', 'NN'), ('he', 'PRP'), ('thought', 'VBD'), ('was', 'VBD'), ('on', 'IN'), ('his', 'PRP$'), ('side', 'NN'), ('broke', 'VBD'), ('his', 'PRP$'), ('neck', 'NN'), ('.', '.')]),
#  Tree('S', [('Do', 'VB'), ('you', 'PRP'), ('all', 'DT'), ('trust', 'VB'), ('me', 'PRP'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('trust', 'VB'), ('any', 'DT'), ('of', 'IN'), ('you', 'PRP'), ('.', '.')]),
#  Tree('S', [('All', 'DT'), ('right', 'JJ'), ('.', '.'), ('We', 'PRP'), ('should', 'MD'), ('focus', 'VB'), ('on', 'IN'), ('protecting', 'VBG'), ('ourselves', 'PRP'), ('first', 'RB'), ('.', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'POS'), ('set', 'VB'), ('up', 'RP'), ('a', 'DT'), ('barricade', 'NN'), ('before', 'IN'), ('the', 'DT'), ('lights', 'NNS'), ('go', 'VBP'), ('out', 'RP'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ("'ll", 'MD'), ('help', 'VB'), ('to', 'TO'), ('have', 'VB'), ('some', 'DT'), ('form', 'NN'), ('of', 'IN'), ('cover', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Hey', 'NNP')]), (',', ','), Tree('PERSON', [('Mr.', 'NNP'), ('Ssangmun-dong', 'NNP')]), ('.', '.')]),
#  Tree('S', [('So', 'RB'), ('desperate', 'JJ'), ('to', 'TO'), ('stay', 'VB'), ('alive', 'JJ'), ('.', '.')]),
#  Tree('S', [('But…', 'NN')]),
#  Tree('S', [('you', 'PRP'), ('really', 'RB'), ('think', 'VBP'), ('this', 'DT'), ('will', 'MD'), ('help', 'VB'), ('?', '.')]),
#  Tree('S', [('It', 'PRP'), ('looks', 'VBZ'), ('really', 'RB'), ('drafty', 'JJ'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ('about', 'IN'), ('you', 'PRP'), ('?', '.')]),
#  Tree('S', [('Those', 'DT'), ('scumbags', 'NNS'), ('on', 'IN'), ('your', 'PRP$'), ('so-called', 'JJ'), ('team', 'NN'), ('.', '.')]),
#  Tree('S', [('Do', 'VB'), ('you', 'PRP'), ('really', 'RB'), ('trust', 'VB'), ('them', 'PRP'), ('?', '.')]),
#  Tree('S', [('Try', 'VB'), ('it', 'PRP'), (',', ','), ('bitch', 'NN'), ('.', '.')]),
#  Tree('S', [('Go', 'NNP'), ('ahead', 'RB'), ('.', '.'), ('Bring', 'VB'), ('it', 'PRP'), ('on', 'IN'), ('.', '.'), ('If', 'IN'), ('I', 'PRP'), ('were', 'VBD'), ('one', 'CD'), ('of', 'IN'), ('them', 'PRP'), (',', ',')]),
#  Tree('S', [('If', 'IN'), ('I', 'PRP'), ('were', 'VBD'), ('one', 'CD'), ('of', 'IN'), ('them', 'PRP'), (',', ',')]),
#  Tree('S', [('once', 'RB'), ('the', 'DT'), ('fighting', 'NN'), ('starts', 'VBZ'), ('at', 'IN'), ('night', 'NN'), (',', ',')]),
#  Tree('S', [('I', 'PRP'), ("'d", 'MD'), ('take', 'VB'), ('the', 'DT'), ('chance', 'NN'), ('to', 'TO'), ('kill', 'VB'), ('you', 'PRP'), ('first', 'RB'), ('.', '.')]),
#  Tree('S', [('After', 'IN'), ('all', 'DT'), (',', ','), ('you', 'PRP'), ("'re", 'VBP'), ('the', 'DT'), ('strongest', 'JJS'), ('one', 'NN'), ('.', '.')]),
#  Tree('S', [('How', 'WRB'), ("'s", 'VBZ'), ('that', 'DT'), ('?', '.')]),
#  Tree('S', [Tree('GPE', [('Boss', 'NNP')]), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Which', 'JJ')]), ('team', 'NN'), ('should', 'MD'), ('we', 'PRP'), ('crush', 'VB'), ('first', 'RB'), ('?', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'POS'), ('take', 'VB'), ('the', 'DT'), ('night', 'NN'), ('off', 'RP'), ('.', '.')]),
#  Tree('S', [('Why', 'WRB'), ('?', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'POS'), ('cut', 'VB'), ('down', 'RP'), ('the', 'DT'), ('numbers', 'NNS'), ('--', ':')]),
#  Tree('S', [('I', 'PRP'), ('said', 'VBD'), ('we', 'PRP'), ('rest', 'VBP'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Okay', 'NNP')]), ('.', '.')]),
#  Tree('S', [('Hey', 'NNP'), ('.', '.')]),
#  Tree('S', [('All', 'DT'), ('of', 'IN'), ('you', 'PRP'), (',', ','), ('put', 'VB'), ('those', 'DT'), ('down', 'NNS'), ('and', 'CC'), ('get', 'VB'), ('some', 'DT'), ('rest', 'NN'), ('.', '.')]),
#  Tree('S', [('Where', 'WRB'), ("'s", 'VBZ'), ('the', 'DT'), ('doc', 'NN'), ('?', '.')]),
#  Tree('S', [('He', 'PRP'), ('went', 'VBD'), ('out', 'IN'), ('to', 'TO'), ('the', 'DT'), ('restroom', 'NN'), ('a', 'DT'), ('moment', 'NN'), ('ago', 'RB'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('lights', 'NNS'), ('will', 'MD'), ('go', 'VB'), ('out', 'RP'), ('soon', 'RB'), ('.', '.')]),
#  Tree('S', [('They', 'PRP'), ('wo', 'MD'), ("n't", 'RB'), ('be', 'VB'), ('able', 'JJ'), ('to', 'TO'), ('easily', 'RB'), ('attack', 'VB'), ('us', 'PRP'), (',', ',')]),
#  Tree('S', [('but', 'CC'), ('let', 'VB'), ("'s", 'PRP'), ('take', 'VB'), ('turns', 'NNS'), ('keeping', 'VBG'), ('watch', 'NN'), ('just', 'RB'), ('in', 'IN'), ('case', 'NN'), ('.', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'PRP'), ('do', 'VB'), ('it', 'PRP'), ('in', 'IN'), ('pairs', 'NNS'), ('.', '.')]),
#  Tree('S', [('There', 'EX'), ("'s", 'VBZ'), ('a', 'DT'), ('chance', 'NN'), ('one', 'CD'), ('person', 'NN'), ('might', 'MD'), ('fall', 'VB'), ('asleep', 'NN')]),
#  Tree('S', [('or', 'CC'), ('side', 'NN'), ('with', 'IN'), ('another', 'DT'), ('team', 'NN'), ('to', 'TO'), ('betray', 'VB'), ('us', 'PRP'), ('.', '.')]),
#  Tree('S', [("I'll…", 'NNP'), ('go', 'VBP'), ('first', 'RB'), ('.', '.')]),
#  Tree('S', [('Old', 'NNP'), ('people', 'NNS'), ('do', 'VBP'), ("n't", 'RB'), ('get', 'VB'), ('very', 'RB'), ('sleepy', 'RB'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Hey', 'NNP')]), (',', ','), ('how', 'WRB'), ('can', 'MD'), ('we', 'PRP'), ('trust', 'VB'), ('an', 'DT'), ('old', 'JJ'), ('man', 'NN'), ('like', 'IN'), ('you', 'PRP'), ('and', 'CC'), ('fall', 'VB'), ('asleep', 'RB'), ('in', 'IN'), ('peace', 'NN'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ("'ll", 'MD'), ('go', 'VB'), ('first', 'RB'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'ll", 'MD'), ('join', 'VB'), ('you', 'PRP'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('not', 'RB'), ('sleepy', 'JJ'), ('right', 'RB'), ('now', 'RB'), ('.', '.')]),
#  Tree('S', [('Then', 'RB'), ('I', 'PRP'), ("'ll", 'MD'), ('go', 'VB'), ('next', 'RB'), ('.', '.')]),
#  Tree('S', [('Wake', 'VB'), ('me', 'PRP'), ('up', 'RP'), ('when', 'WRB'), ('you', 'PRP'), ('get', 'VBP'), ('tired', 'VBN'), ('.', '.')]),
#  Tree('S', [('Then', 'RB'), ('I', 'PRP'), ("'ll", 'MD'), ('join', 'VB'), ('you', 'PRP'), ('if', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('okay', 'JJ'), ('with', 'IN'), ('that', 'DT'), ('.', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'POS'), ('do', 'VB'), ('that', 'DT'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('day', 'NN'), ("'s", 'POS'), ('work', 'NN'), ('has', 'VBZ'), ('been', 'VBN'), ('completed', 'VBN'), ('.', '.')]),
#  Tree('S', [('All', 'DT'), ('workers', 'NNS'), (',', ','), ('please', 'VB'), ('return', 'VB'), ('to', 'TO'), ('your', 'PRP$'), ('quarters', 'NNS'), ('.', '.')]),
#  Tree('S', [('All', 'DT'), ('workers', 'NNS'), (',', ','), ('please', 'VB'), ('return', 'VB'), ('to', 'TO'), ('your', 'PRP$'), ('quarters', 'NNS'), ('immediately', 'RB'), ('.', '.')]),
#  Tree('S', [('Have', 'VB'), ('this', 'DT'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('saved', 'VBD'), ('it', 'PRP'), ('from', 'IN'), ('dinner', 'NN'), ('earlier', 'RBR'), ('.', '.')]),
#  Tree('S', [('To', 'TO'), ('give', 'VB'), ('it', 'PRP'), ('to', 'TO'), ('you', 'PRP'), (',', ','), ('sir', 'VB'), ('.', '.')]),
#  Tree('S', [('Why', 'WRB'), ('would', 'MD'), ('you', 'PRP'), ('do', 'VB'), ('that', 'DT'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ('saved', 'VBD'), ('my', 'PRP$'), ('life', 'NN'), ('today', 'NN'), (',', ','), ('sir', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('wanted', 'VBD'), ('to', 'TO'), ('thank', 'VB'), ('you', 'PRP'), ('.', '.')]),
#  Tree('S', [('There', 'EX'), ("'s", 'VBZ'), ('no', 'DT'), ('need', 'NN'), ('to', 'TO'), ('thank', 'VB'), ('me', 'PRP'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('did', 'VBD'), ('it', 'PRP'), ('to', 'TO'), ('save', 'VB'), ('myself', 'PRP'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('gave', 'VBD'), ('me', 'PRP'), ('the', 'DT'), ('bus', 'NN'), ('fare', 'NN'), ('too', 'RB'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('should', 'MD'), ('return', 'VB'), ('the', 'DT'), ('favor', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Happy', 'JJ')]), ('?', '.')]),
#  Tree('S', [('Your', 'PRP$'), ('name', 'NN'), ('is', 'VBZ'), Tree('PERSON', [('Ali', 'NNP')]), (',', ','), ('right', 'RB'), ('?', '.')]),
#  Tree('S', [('How', 'WRB'), ('old', 'JJ'), ('are', 'VBP'), ('you', 'PRP'), ('?', '.')]),
#  Tree('S', [Tree('GPE', [('Ali', 'NNP')]), ('is', 'VBZ'), ('33', 'CD'), ('years', 'NNS'), ('old', 'JJ'), ('.', '.')]),
#  Tree('S', [('Then', 'RB'), ('just', 'RB'), ('call', 'VB'), ('me', 'PRP'), ('Sang-woo', 'NNP'), ('.', '.')]),
#  Tree('S', [('May', 'NNP'), ('I', 'PRP'), ('do', 'VBP'), ('that…', 'VB')]),
#  Tree('S', [('Sang-woo', 'NNP'), ('?', '.')]),
#  Tree('S', [('How', 'WRB'), ('did', 'VBD'), ('you', 'PRP'), ('end', 'VB'), ('up', 'RP'), ('here', 'RB'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ('came', 'VBD'), ('to', 'TO'), Tree('GPE', [('Korea', 'NNP')]), ('to', 'TO'), ('make', 'VB'), ('money…', 'NN')]),
#  Tree('S', [('Sang-woo', 'NNP'), ('.', '.')]),
#  Tree('S', [('No', 'DT'), (',', ','), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('mean', 'VB'), Tree('GPE', [('Korea', 'NNP')]), ('.', '.'), ('Here', 'RB'), ('.', '.')]),
#  Tree('S', [('This', 'DT'), ('game', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('came', 'VBD'), ('because…', 'NN'), ('I', 'PRP'), ('had', 'VBD'), ('no', 'DT'), ('money', 'NN'), ('.', '.')]),
#  Tree('S', [('Any', 'DT'), ('family', 'NN'), ('?', '.')]),
#  Tree('S', [('My', 'PRP$'), ('mom', 'NN'), (',', ','), ('dad', 'NN'), (',', ','), ('and', 'CC'), ('younger', 'JJR'), ('siblings', 'NNS'), ('are', 'VBP'), ('in', 'IN'), Tree('GPE', [('Pakistan', 'NNP')]), ('.', '.')]),
#  Tree('S', [('And', 'CC'), ('I', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('wife', 'NN'), ('and', 'CC'), ('baby', 'NN'), ('in', 'IN'), Tree('GPE', [('Korea', 'NNP')]), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('kid', 'NN'), ('?', '.')]),
#  Tree('S', [('How', 'WRB'), ('old', 'JJ'), ('?', '.')]),
#  Tree('S', [('A', 'DT'), ('one-year-old', 'JJ'), ('son', 'NN'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('must', 'MD'), ('miss', 'VB'), ('them', 'PRP'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('do', 'VBP'), ('.', '.')]),
#  Tree('S', [('How', 'WRB'), ('did', 'VBD'), ('you', 'PRP'), ('end', 'VB'), ('up', 'RP')]),
#  Tree('S', [('here', 'RB'), ('?', '.')]),
#  Tree('S', [('Because', 'IN'), ('I', 'PRP'), ('had', 'VBD'), ('no', 'DT'), ('money', 'NN'), ('.', '.')]),
#  Tree('S', [('To', 'TO'), ('make', 'VB'), ('money', 'NN'), ('.', '.')]),
#  Tree('S', [('Number', 'NNP'), ('29', 'CD'), (',', ',')]),
#  Tree('S', [('what', 'WP'), ('happened', 'VBD'), ('yesterday', 'NN'), ('?', '.'), ('Why', 'WRB'), ('did', 'VBD'), ("n't", 'RB'), ('you', 'PRP'), ('show', 'VB'), ('up', 'RP'), ('?', '.')]),
#  Tree('S', [Tree('PERSON', [('Sorry', 'NNP')]), ('.', '.')]),
#  Tree('S', [('``', '``'), Tree('PERSON', [('Sorry', 'NN')]), ("''", "''"), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ('had', 'VBD'), ('to', 'TO'), ('stop', 'VB'), ('the', 'DT'), ('others', 'NNS'), ('from', 'IN'), ('killing', 'VBG'), ('you', 'PRP'), ('.', '.'), ('They', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('trust', 'VB'), ('you', 'PRP'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('owed', 'VBD'), ('you', 'PRP'), ('for', 'IN'), ('saving', 'VBG'), ('my', 'PRP$'), ('life', 'NN'), ('on', 'IN'), ('our', 'PRP$'), ('last', 'JJ'), ('dive', 'JJ'), ('.', '.'), ('Now', 'RB'), ('we', 'PRP'), ("'re", 'VBP'), ('even', 'RB'), ('.', '.')]),
#  Tree('S', [('One', 'CD'), ('more', 'JJR'), ('strike', 'NN'), ('and', 'CC'), ('you', 'PRP'), ("'re", 'VBP'), ('out', 'RP'), ('.', '.')]),
#  Tree('S', [('Number', 'NNP'), ('29', 'CD'), ('.', '.'), ('You', 'PRP'), ("'re", 'VBP'), ('finally', 'RB'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('gave', 'VBD'), ('him', 'PRP'), ('a', 'DT'), ('warning', 'NN'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ('could', 'MD'), ("n't", 'RB'), ('make', 'VB'), ('the', 'DT'), ('delivery', 'NN'), ('last', 'JJ'), ('night', 'NN'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ('ca', 'MD'), ("n't", 'RB'), ('let', 'VB'), ('it', 'PRP'), ('slide', 'VB'), ('with', 'IN'), ('a', 'DT'), ('warning', 'NN'), ('!', '.')]),
#  Tree('S', [('Then', 'RB'), ('you', 'PRP'), ('can', 'MD'), ('deliver', 'VB'), ('it', 'PRP'), ('yourself', 'PRP'), ('.', '.')]),
#  Tree('S', [('Do', 'VBP'), ('you', 'PRP'), ('think', 'VB'), ('it', 'PRP'), ("'s", 'VBZ'), ('easy', 'JJ'), ('to', 'TO'), ('find', 'VB'), ('divers', 'NNS'), ('like', 'IN'), ('us', 'PRP'), ('in', 'IN'), ('this', 'DT'), ('place', 'NN'), ('?', '.')]),
#  Tree('S', [Tree('GPE', [('Make', 'NNP')]), ('sure', 'JJ'), ('today', 'NN'), ("'s", 'POS'), ('delivery', 'NN'), ('goes', 'VBZ'), ('without', 'IN'), ('a', 'DT'), ('hitch', 'NN'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ('?', '.'), ('You', 'PRP'), ("'re", 'VBP'), ('not', 'RB'), ('even', 'RB'), ('done', 'VBN'), ('with', 'IN'), ('one', 'CD'), ('?', '.')]),
#  Tree('S', [('The', 'DT'), ('doctor', 'NN'), ('is', 'VBZ'), ('much', 'RB'), ('slower', 'JJR'), ('than', 'IN'), ('usual', 'JJ'), ('today', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Hey', 'NNP')]), (',', ','), ('quack', 'NN'), ('.', '.'), Tree('PERSON', [('Hurry', 'NNP')]), ('up', 'RB'), ('.', '.')]),
#  Tree('S', [('This', 'DT'), ('all', 'DT'), ('goes', 'VBZ'), ('to', 'TO'), ('waste', 'VB'), ('if', 'IN'), ('the', 'DT'), ('ship', 'NN'), ('leaves', 'VBZ'), ('before', 'IN'), ('we', 'PRP'), ('deliver', 'VBP'), ('.', '.')]),
#  Tree('S', [('Try', 'VB'), ('doing', 'VBG'), ('this', 'DT'), ('with', 'IN'), ('no', 'DT'), ('sleep', 'NN'), ('and', 'CC'), ('only', 'RB'), ('crappy', 'JJ'), ('food', 'NN'), (',', ',')]),
#  Tree('S', [('barely', 'RB'), ('escaping', 'VBG'), ('death', 'NN'), ('every', 'DT'), ('day', 'NN'), ('.', '.')]),
#  Tree('S', [('So', 'IN'), ('we', 'PRP'), ('tell', 'VBP'), ('you', 'PRP'), ('what', 'WP'), ('the', 'DT'), ('game', 'NN'), ('is', 'VBZ')]),
#  Tree('S', [('and', 'CC'), ('give', 'VB'), ('you', 'PRP'), ('extra', 'JJ'), ('food', 'NN'), ('to', 'TO'), ('make', 'VB'), ('sure', 'JJ'), ('you', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('die', 'VB'), ('.', '.')]),
#  Tree('S', [('Gi-hun', 'NNP'), ('.', '.')]),
#  Tree('S', [('Sang-woo', 'NNP'), ('.', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'POS'), ('switch', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Okay', 'NNP')]), (',', ','), ('sure', 'NN'), ('.', '.')]),
#  Tree('S', [('Will', 'MD'), ('you', 'PRP'), ('be', 'VB'), ('okay', 'VBN'), ('?', '.')]),
#  Tree('S', [('What', 'WP'), ('?', '.')]),
#  Tree('S', [('Looks', 'NNS'), ('like', 'IN'), ('you', 'PRP'), ('were', 'VBD'), ('having', 'VBG'), ('a', 'DT'), ('nightmare', 'NN'), ('.', '.')]),
#  Tree('S', [('No', 'DT'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('fine', 'JJ'), ('.', '.')]),
#  Tree('S', [('Hey', 'NNP'), ('.', '.')]),
#  Tree('S', [('Why', 'WRB'), ('are', 'VBP'), ("n't", 'RB'), ('you', 'PRP'), ('sleeping', 'VBG'), (',', ','), ('boss', 'NN'), ('?', '.')]),
#  Tree('S', [('Ca', 'NNP'), ("n't", 'RB'), ('fall', 'VB'), ('asleep', 'VB'), ('for', 'IN'), ('some', 'DT'), ('reason', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('keeping', 'VBG'), ('everyone', 'NN'), ('safe', 'JJ'), ('.', '.')]),
#  Tree('S', [('Do', 'VBP'), ("n't", 'RB'), ('worry', 'VB'), ('and', 'CC'), ('go', 'VB'), ('to', 'TO'), ('sleep', 'VB'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('trust', 'VBP'), ('you', 'PRP'), (',', ','), ('punk', 'NN'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('doc', 'NN'), ("'s", 'POS'), ('still', 'RB'), ('not', 'RB'), ('back', 'RB'), ('?', '.')]),
#  Tree('S', [('No', 'DT'), ('.', '.'), ('It', 'PRP'), ("'s", 'VBZ'), ('weird', 'JJ'), ('.', '.'), ('He', 'PRP'), ('went', 'VBD'), ('to', 'TO'), ('the', 'DT'), ('bathroom', 'NN'), ('ages', 'VBZ'), ('ago', 'RB'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('weird', 'JJ'), ('.', '.'), ('He', 'PRP'), ('went', 'VBD'), ('to', 'TO'), ('the', 'DT'), ('bathroom', 'NN'), ('ages', 'VBZ'), ('ago', 'RB'), ('.', '.')]),
#  Tree('S', [('Hold', 'VB'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ("'re", 'VBP'), ('in', 'IN'), ('a', 'DT'), ('hurry', 'NN'), ('.', '.'), ('Should', 'MD'), ('I', 'PRP'), ('try', 'VB'), ('working', 'VBG'), ('on', 'IN'), ('those', 'DT'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ('think', 'VBP'), ('I', 'PRP'), ('can', 'MD'), ('do', 'VB'), ('it', 'PRP'), ('if', 'IN'), ('you', 'PRP'), ('teach', 'VBP'), ('me', 'PRP'), ('a', 'DT'), ('few', 'JJ'), ('tricks', 'NNS'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('think', 'VBP'), ('this', 'DT'), ('is', 'VBZ'), ('easy', 'JJ'), ('just', 'RB'), ('because', 'IN'), ('I', 'PRP'), ("'m", 'VBP'), ('here', 'RB'), ('like', 'IN'), ('this', 'DT'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ('saw', 'VBD'), ('on', 'IN'), ('the', 'DT'), ('news', 'NN'), ('that', 'IN'), ('nurses', 'VBZ'), ("'", 'POS'), ('aides', 'NNS'), ('and', 'CC'), ('office', 'NN'), ('managers', 'NNS'), ('often', 'RB'), ('perform', 'VBP'), ('surgery', 'NN'), ('.', '.')]),
#  Tree('S', [('And', 'CC'), ('some', 'DT'), ('of', 'IN'), ('them', 'PRP'), ('are', 'VBP'), ('better', 'JJR'), ('than', 'IN'), ('doctors', 'NNS'), ('.', '.')]),
#  Tree('S', [('If', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('so', 'RB'), ('confident', 'JJ'), (',', ','), ('do', 'VB'), ('it', 'PRP'), ('yourself', 'PRP'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('have', 'VBP'), ('a', 'DT'), ('lot', 'NN'), ('of', 'IN'), ('pride', 'NN'), ('for', 'IN'), ('a', 'DT'), ('quack', 'NN'), ('who', 'WP'), ('killed', 'VBD'), ('someone', 'NN'), ('through', 'IN'), ('negligence', 'NN'), ('.', '.')]),
#  Tree('S', [('If', 'IN'), ('you', 'PRP'), ("'re", 'VBP'), ('so', 'RB'), ('good', 'JJ'), (',', ','), ('how', 'WRB'), ("'d", 'MD'), ('you', 'PRP'), ('ruin', 'VB'), ('the', 'DT'), ('eyeballs', 'NNS'), ('last', 'JJ'), ('time', 'NN'), ('?', '.')]),
#  Tree('S', [('Got', 'NNP'), ('a', 'DT'), ('ton', 'NN'), ('of', 'IN'), ('shit', 'NN'), ('from', 'IN'), ('the', 'DT'), Tree('GPE', [('Chinese', 'JJ')]), ('buyers', 'NNS'), ('!', '.')]),
#  Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('because', 'IN'), ('you', 'PRP'), ('put', 'VBP'), ('someone', 'NN'), ('alive', 'NN'), ('on', 'IN'), ('the', 'DT'), ('operating', 'NN'), ('table', 'NN'), ('.', '.')]),
#  Tree('S', [('Everything', 'VBG'), ('went', 'VBD'), ('to', 'TO'), ('shit', 'VB'), ('when', 'WRB'), ('he', 'PRP'), ('woke', 'VBD'), ('up', 'RB'), ('and', 'CC'), ('started', 'VBD'), ('struggling', 'VBG'), ('!', '.')]),
#  Tree('S', [('We', 'PRP'), ('have', 'VBP'), ('no', 'DT'), ('time', 'NN'), ('for', 'IN'), ('this', 'DT'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('ship', 'NN'), ('will', 'MD'), ('arrive', 'VB'), ('soon', 'RB'), ('.', '.')]),
#  Tree('S', [('Gi-hun', 'NNP'), ('.', '.')]),
#  Tree('S', [('Hey', 'NNP'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ('are', 'VBP'), ('you', 'PRP'), ('so', 'RB'), ('deep', 'JJ'), ('in', 'IN'), ('thought', 'NN'), ('about', 'IN'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ('thought', 'VBD'), ('you', 'PRP'), ('were', 'VBD'), ('sleeping', 'VBG'), ('with', 'IN'), ('your', 'PRP$'), ('eyes', 'NNS'), ('open', 'VBP'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('was', 'VBD'), ('thinking', 'VBG'), ('about', 'IN'), ('the', 'DT'), ('past', 'NN'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('past', 'NN'), ('?', '.')]),
#  Tree('S', [('We', 'PRP'), ('once', 'RB'), ('went', 'VBD'), ('on', 'IN'), ('strike', 'NN'), ('at', 'IN'), ('my', 'PRP$'), ('old', 'JJ'), ('company', 'NN'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ('set', 'VBP'), ('up', 'RP'), ('a', 'DT'), ('barricade', 'NN'), ('like', 'IN'), ('this', 'DT'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ('kind', 'NN'), ('of', 'IN'), ('company', 'NN'), ('did', 'VBD'), ('you', 'PRP'), ('work', 'VB'), ('for', 'IN'), ('?', '.')]),
#  Tree('S', [('A', 'DT'), ('car', 'NN'), ('company', 'NN'), ('.', '.')]),
#  Tree('S', [('Why', 'WRB'), ('were', 'VBD'), ('you', 'PRP'), ('on', 'IN'), ('strike', 'NN'), ('?', '.')]),
#  Tree('S', [('They', 'PRP'), ('fired', 'VBD'), ('us', 'PRP'), ('because', 'IN'), ('they', 'PRP'), ('were', 'VBD'), ('in', 'IN'), ('financial', 'JJ'), ('trouble', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'d", 'MD'), ('worked', 'VBN'), ('there', 'RB'), ('for', 'IN'), ('over', 'IN'), ('a', 'DT'), ('decade', 'NN'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('must', 'MD'), ("'ve", 'VBP'), ('been', 'VBN'), ('tough', 'JJ'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('was', 'VBD'), ('just', 'RB'), ('about', 'RB'), ('to', 'TO'), ('have', 'VB'), ('a', 'DT'), ('baby', 'NN'), (',', ',')]),
#  Tree('S', [('and', 'CC'), ('I', 'PRP'), ('had', 'VBD'), ('a', 'DT'), ('million', 'CD'), ('things', 'NNS'), ('to', 'TO'), ('pay', 'VB'), ('for', 'IN'), ('.', '.')]),
#  Tree('S', [('They', 'PRP'), ('suddenly', 'RB'), ('told', 'VBD'), ('us', 'PRP'), ('to', 'TO'), ('leave', 'VB'), (',', ','), ('so', 'IN'), ('I', 'PRP'), ('had', 'VBD'), ('no', 'DT'), ('alternative', 'NN'), ('.', '.')]),
#  Tree('S', [('They', 'PRP'), ('were', 'VBD'), ('the', 'DT'), ('ones', 'NNS'), ('who', 'WP'), ('ruined', 'VBD'), ('the', 'DT'), ('company', 'NN'), ('but', 'CC'), ('held', 'VBD'), ('us', 'PRP'), ('responsible', 'JJ'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('made', 'VBD'), ('me', 'PRP'), ('furious', 'JJ'), ('.', '.')]),
#  Tree('S', [('Just', 'RB'), ('like', 'IN'), ('now', 'RB'), (',', ',')]),
#  Tree('S', [('we', 'PRP'), ('kept', 'VBD'), ('watch', 'NN'), ('while', 'IN'), ('my', 'PRP$'), ('colleagues', 'NNS'), ('and', 'CC'), ('I', 'PRP'), ('occupied', 'VBD'), ('the', 'DT'), ('factory', 'NN'), ('.', '.')]),
#  Tree('S', [('Scared', 'VBD'), ('the', 'DT'), ('police', 'NN'), ('might', 'MD'), ('barge', 'VB'), ('in', 'IN'), ('any', 'DT'), ('minute', 'NN'), (',', ',')]),
#  Tree('S', [('we', 'PRP'), ('trembled', 'VBD'), ('every', 'DT'), ('night', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('remember', 'VBP'), ('.', '.'), ('About', 'IN'), ('ten', 'CD'), ('years', 'NNS'), ('ago', 'RB'), ('or', 'CC'), ('so', 'RB'), (',', ',')]),
#  Tree('S', [('there', 'EX'), ('was', 'VBD'), ('a', 'DT'), ('big', 'JJ'), ('strike', 'NN'), ('at', 'IN'), ('a', 'DT'), ('car', 'NN'), ('company', 'NN'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('was', 'VBD'), ('big', 'JJ'), ('news', 'NN'), ('back', 'RB'), ('then', 'RB'), ('.', '.')]),
#  Tree('S', [Tree('PERSON', [('Someone', 'NN')]), ('died', 'VBD'), ('there', 'RB'), (',', ','), ('right', 'RB'), ('?', '.')]),
#  Tree('S', [('Yes', 'UH'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Goodness', 'NNP')]), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('sorry', 'JJ'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("shouldn't…", 'VBP')]),
#  Tree('S', [('have', 'VBP'), ('mentioned', 'VBN'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Sir', 'NNP')]), ('.', '.')]),
#  Tree('S', [('Are', 'NNP'), ('you', 'PRP'), ('okay', 'IN'), ('?', '.')]),
#  Tree('S', [('-You', 'JJ'), ("'re", 'VBP'), ('burning', 'VBG'), ('up', 'RP'), ('.', '.'), ('-It', 'NN'), ("'s", 'POS'), ('okay', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('nearly', 'RB'), ('wet', 'VBP'), ('my', 'PRP$'), ('pants', 'NNS'), ('that', 'IN'), ('night', 'NN'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ('I', 'PRP'), ('thought', 'VBD'), ('was', 'VBD'), ('a', 'DT'), ('dead', 'JJ'), ('body', 'NN'), ('suddenly', 'RB'), ('jumped', 'VBD'), ('up', 'RP'), ('like', 'IN'), ('a', 'DT'), ('zombie', 'NN'), (',', ',')]),
#  Tree('S', [('and', 'CC'), ('glared', 'VBN'), ('at', 'IN'), ('me', 'PRP'), ('with', 'IN'), ('one', 'CD'), ('eye', 'NN'), ('popping', 'VBG'), ('out', 'RP'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('dreamed', 'VBD'), ('about', 'IN'), ('it', 'PRP'), ('last', 'JJ'), ('night', 'NN'), ('.', '.')]),
#  Tree('S', [('Everyone', 'NN'), ('who', 'WP'), ('failed', 'VBD'), Tree('PERSON', [('Red', 'NNP'), ('Light', 'NNP')]), (',', ','), Tree('PERSON', [('Green', 'NNP'), ('Light', 'NNP')]), ('was', 'VBD'), ('shot', 'VBN'), ('by', 'IN'), ('a', 'DT'), ('sniper', 'NN'), ('rifle', 'NN'), (',', ',')]),
#  Tree('S', [('so', 'IN'), ('we', 'PRP'), ('could', 'MD'), ('hardly', 'RB'), ('salvage', 'VB'), ('anything', 'NN'), ('.', '.')]),
#  Tree('S', [('That', 'DT'), ('zombie', 'NN'), ('was', 'VBD'), ('the', 'DT'), ('most', 'RBS'), ('decent', 'JJ'), ('looking', 'VBG'), ('of', 'IN'), ('the', 'DT'), ('bunch', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('almost', 'RB'), ('died', 'VBD'), ('delivering', 'VBG'), ('that', 'DT'), ('day', 'NN'), (',', ',')]),
#  Tree('S', [('but', 'CC'), ('we', 'PRP'), ('did', 'VBD'), ("n't", 'RB'), ('even', 'RB'), ('get', 'VB'), ('full', 'JJ'), ('price', 'NN'), ('because', 'IN'), ('it', 'PRP'), ('only', 'RB'), ('had', 'VBD'), ('one', 'CD'), ('kidney', 'NN'), ('.', '.')]),
#  Tree('S', [('Is', 'VBZ'), ('it', 'PRP'), ('my', 'PRP$'), ('fault', 'NN'), ('that', 'IN'), ('the', 'DT'), ('zombie', 'NN'), ('only', 'RB'), ('had', 'VBD'), ('one', 'CD'), ('kidney', 'NN'), ('?', '.')]),
#  Tree('S', [('This', 'DT'), ('guy', 'NN'), ("'s", 'POS'), ('organs', 'NNS'), ('are', 'VBP'), ('intact', 'JJ'), ('?', '.')]),
#  Tree('S', [('Most', 'JJS'), ('of', 'IN'), ('the', 'DT'), ('people', 'NNS'), ('here', 'RB'), ('either', 'RB'), ('signed', 'VBN'), ('away', 'RP'), ('their', 'PRP$'), ('bodies', 'NNS'), ('or', 'CC'), ('are', 'VBP'), ('terminally', 'RB'), ('ill', 'JJ'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('feel', 'VB'), ('great', 'JJ'), ('about', 'IN'), ('this', 'DT'), ('.', '.')]),
#  Tree('S', [('Lie', 'NNP'), ('down', 'RB'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Wait', 'NNP')]), ('here', 'RB'), ('.', '.'), ('We', 'PRP'), ('need', 'VBP'), ('your', 'PRP$'), ('fever', 'NN'), ('to', 'TO'), ('break', 'VB'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ('need', 'VBP'), ('your', 'PRP$'), ('fever', 'NN'), ('to', 'TO'), ('break', 'VB'), ('.', '.')]),
#  Tree('S', [('Damn', 'NN'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [('Use', 'VB'), ('this', 'DT'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ('happened…', 'NN')]),
#  Tree('S', [('to', 'TO'), ('that', 'DT'), ('zombie', 'NN'), ('?', '.')]),
#  Tree('S', [('What', 'WP'), ('do', 'VBP'), ('you', 'PRP'), ('think', 'VB'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ('just', 'RB'), ('beat', 'VB'), ('it', 'PRP'), ('to', 'TO'), ('death', 'NN'), ('with', 'IN'), ('that', 'DT'), ('over', 'IN'), ('there', 'RB'), ('.', '.')]),
#  Tree('S', [('Why', 'WRB'), ('do', 'VBP'), ('you', 'PRP'), ('ask', 'VB'), (',', ','), ('though', 'IN'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ('saw', 'VBD'), ('it', 'PRP'), ('all', 'DT'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ("'s", 'VBZ'), ('wrong', 'JJ'), ('with', 'IN'), ('you', 'PRP'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('remember', 'VB'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ('was', 'VBD'), ('just…', 'NN')]),
#  Tree('S', [('I', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('bit', 'NN'), ('out', 'IN'), ('of', 'IN'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('were', 'VBD'), ('out', 'IN'), ('of', 'IN'), ('it', 'PRP'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ('even', 'RB'), ('got', 'VBD'), ('rid', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('body', 'NN'), ('with', 'IN'), ('your', 'PRP$'), ('own', 'JJ'), ('hands', 'NNS'), ('.', '.')]),
#  Tree('S', [('Number', 'NNP'), ('29', 'CD'), ('.', '.')]),
#  Tree('S', [('-You', 'NN'), ('--', ':'), ('-This', 'NN'), ('is', 'VBZ'), ('my', 'PRP$'), ('operating', 'NN'), ('room', 'NN'), ('!', '.')]),
#  Tree('S', [('Cut', 'VB'), ('the', 'DT'), ('crap', 'NN'), ('and', 'CC'), ('hold', 'VB'), ('this', 'DT'), ('properly', 'JJ'), ('!', '.')]),
#  Tree('S', [Tree('GPE', [('Focus', 'NN')]), ('on', 'IN'), ('the', 'DT'), ('work', 'NN'), ('!', '.')]),
#  Tree('S', [('Or', 'CC'), ('else', 'RB'), (',', ','), ('liver', 'RB'), (',', ','), ('kidney', 'NN'), (',', ','), ('whatever', 'WDT'), ('.', '.'), ('I', 'PRP'), ("'ll", 'MD'), ('cut', 'VB'), ('through', 'IN'), ('it', 'PRP'), ('all', 'DT'), ('!', '.')]),
#  Tree('S', [('Thank', 'NNP'), ('you', 'PRP'), ('.', '.')]),
#  Tree('S', [('Get', 'VB'), ('some', 'DT'), ('rest', 'NN'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('need', 'VBP'), ('to', 'TO'), ('get', 'VB'), ('better', 'JJR'), ('and', 'CC'), ('play', 'VB'), ('another', 'DT'), ('game', 'NN'), ('with', 'IN'), ('us', 'PRP'), ('tomorrow', 'NN'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('should', 'MD'), ('go', 'VB'), ('back', 'RB'), ('to', 'TO'), ('sleep', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('can', 'MD'), ('do', 'VB'), ('this', 'DT'), ('alone', 'NN'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ('agreed', 'VBD'), ('to', 'TO'), ('do', 'VB'), ('it', 'PRP'), ('in', 'IN'), ('pairs', 'NNS'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('already', 'RB'), ('awake', 'VB'), ('anyway', 'RB'), ('.', '.')]),
#  Tree('S', [('Thanks…', 'NN')]),
#  Tree('S', [('for', 'IN'), ('the', 'DT'), ('water', 'NN'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('for', 'IN'), ('free', 'JJ'), ('.', '.')]),
#  Tree('S', [('Pay', 'VB'), ('me', 'PRP'), ('back', 'RB'), ('tomorrow', 'NN'), ('.', '.')]),
#  Tree('S', [('-Hurry', 'NN'), ('.', '.'), ('-They', 'JJ'), ("'re", 'VBP'), ('in', 'IN'), ('great', 'JJ'), ('condition', 'NN'), ('this', 'DT'), ('time', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Make', 'NNP')]), ('sure', 'NN'), ('you', 'PRP'), ('get', 'VBP'), ('full', 'JJ'), ('price', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('PERSON', [('Hurry', 'NNP')]), ('.', '.'), ('The', 'DT'), ('ship', 'NN'), ('is', 'VBZ'), ('already', 'RB'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('Tell', 'VB'), ('me', 'PRP'), ('now', 'RB'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ("'s", 'VBZ'), ('the', 'DT'), ('next', 'JJ'), ('game', 'NN'), ('?', '.')]),
#  Tree('S', [('We', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('yet', 'RB'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ('do', 'VBP'), ('you', 'PRP'), ('mean', 'VB'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('know', 'VB'), ('?', '.')]),
#  Tree('S', [('We', 'PRP'), ('have', 'VBP'), ("n't", 'RB'), ('been', 'VBN'), ('told', 'VBN'), ('yet', 'RB'), ('.', '.')]),
#  Tree('S', [('Then', 'RB'), ('go', 'VB'), ('ask', 'RB'), ('your', 'PRP$'), ('boss', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('know', 'VBP'), ('there', 'EX'), ("'s", 'VBZ'), ('someone', 'NN'), ('pulling', 'VBG'), ('your', 'PRP$'), ('strings', 'NNS'), ('.', '.')]),
#  Tree('S', [('If', 'IN'), ('he', 'PRP'), ('knew', 'VBD'), (',', ','), ('he', 'PRP'), ('would', 'MD'), ("'ve", 'VBP'), ('told', 'VB'), ('us', 'PRP'), ('already', 'RB'), ('.', '.')]),
#  Tree('S', [('-I', 'JJ'), ("'m", 'VBP'), ('sure', 'JJ'), ('there', 'EX'), ("'s", 'VBZ'), ('a', 'DT'), ('reason', 'NN'), ('.', '.'), ('-That', 'WP'), ("'s", 'VBZ'), ('your', 'PRP$'), ('problem', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('did', 'VBD'), ('everything', 'NN'), ('you', 'PRP'), ('told', 'VBD'), ('me', 'PRP'), ('to', 'TO'), ('.', '.')]),
#  Tree('S', [('Go', 'NNP'), ('tell', 'VBP'), ('him', 'PRP'), ('to', 'TO'), ('find', 'VB'), ('out', 'RP'), ('now', 'RB'), ('!', '.')]),
#  Tree('S', [('Go', 'NNP'), ('back', 'RB'), ('and', 'CC'), ('wait', 'NN'), ('!', '.')]),
#  Tree('S', [('I', 'PRP'), ("'ll", 'MD'), ('tell', 'VB'), ('you', 'PRP'), ('before', 'IN'), ('the', 'DT'), ('game', 'NN'), ('begins', 'VBZ'), ('.', '.')]),
#  Tree('S', [('Fucking', 'VBG'), ('bullshit', 'NN'), ('!', '.')]),
#  Tree('S', [('What', 'WP'), ('is', 'VBZ'), ('it', 'PRP'), ('?', '.')]),
#  Tree('S', [Tree('GPE', [('Pull', 'NNP')]), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Calm', 'NNP')]), ('down', 'RB'), ('.', '.')]),
#  Tree('S', [('If', 'IN'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('find', 'VB'), ('out', 'RP'), ('what', 'WP'), ('the', 'DT'), ('game', 'NN'), ('is', 'VBZ'), (',', ','), ('they', 'PRP'), ("'ll", 'MD'), ('kill', 'VB'), ('me', 'PRP'), ('in', 'IN'), ('here', 'RB'), ('tonight', 'NN'), ('.', '.')]),
#  Tree('S', [('This', 'DT'), ('is', 'VBZ'), ("n't", 'RB'), ('going', 'VBG'), ('to', 'TO'), ('get', 'VB'), ('you', 'PRP'), ('the', 'DT'), ('answer', 'NN'), ('.', '.'), ('Give', 'VB'), ('us', 'PRP'), ('time', 'NN'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ('think', 'VBP'), ('I', 'PRP'), ('trust', 'VBP'), ('scumbags', 'NNS'), ('like', 'IN'), ('you', 'PRP'), ('?', '.')]),
#  Tree('S', [('-What', 'DT'), ('else', 'RB'), ('are', 'VBP'), ('we', 'PRP'), ('supposed', 'VBD'), ('to', 'TO'), ('do', 'VB'), ('?', '.'), ('-You', 'VB'), ('go', 'VB'), ('and', 'CC'), ('find', 'VB'), ('out', 'RP'), ('.', '.')]),
#  Tree('S', [('And', 'CC'), ('you', 'PRP'), ('.', '.')]),
#  Tree('S', [('You', 'PRP'), ("'re", 'VBP'), ('staying', 'VBG'), ('here', 'RB'), ('with', 'IN'), ('me', 'PRP'), ('until', 'IN'), ('he', 'PRP'), ('gets', 'VBZ'), ('back', 'RB'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('more', 'JJR'), ('risky', 'JJ'), ('to', 'TO'), ('stay', 'VB'), ('here', 'RB'), ('like', 'IN'), ('this', 'DT'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('return', 'VB'), ('before', 'IN'), ('morning', 'NN'), ('roll', 'NN'), ('call', 'NN'), ('.', '.')]),
# ...
#  Tree('S', [('You', 'PRP'), ('have', 'VBP'), ('to', 'TO'), ('take', 'VB'), ('the', 'DT'), ('key', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('have', 'VBP'), ('the', 'DT'), ('key', 'NN'), ('to', 'TO'), ('upstairs', 'VB'), ('in', 'IN'), ('my', 'PRP$'), ('right', 'JJ'), ('pocket', 'NN'), ('.', '.')]),
#  Tree('S', [('Do', 'VBP'), ("n't", 'RB'), ('try', 'VB'), ('to', 'TO'), ('pull', 'VB'), ('any', 'DT'), ('shit', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('not', 'RB'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('needs', 'VBZ'), ('it', 'PRP'), ('to', 'TO'), ('enter', 'VB'), ('the', 'DT'), ('control', 'NN'), ('room', 'NN'), ('.', '.')]),
#  Tree('S', [('If', 'IN'), ('you', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('trust', 'VB'), ('me', 'PRP'), (',', ','), ('you', 'PRP'), ('can', 'MD'), ('throw', 'VB'), ('it', 'PRP'), ('to', 'TO'), ('him', 'PRP'), ('yourself', 'PRP'), ('.', '.')]),
#  Tree('S', [('Do', 'VBP'), ("n't", 'RB'), ('touch', 'VB'), ('it', 'PRP'), ('.', '.'), ('-It', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('bomb', 'NN'), ('.', '.'), ('-A', 'VB'), ('bomb', 'NN'), ('?', '.')]),
#  Tree('S', [('-It', 'NN'), ("'s", 'POS'), ('a', 'DT'), ('bomb', 'NN'), ('.', '.'), ('-A', 'VB'), ('bomb', 'NN'), ('?', '.')]),
#  Tree('S', [('This', 'DT'), ('passage', 'NN'), ('was', 'VBD'), ('made', 'VBN'), ('so', 'RB'), ('the', 'DT'), Tree('ORGANIZATION', [('VIPs', 'NNP')]), ('can', 'MD'), ('escape', 'VB'), ('in', 'IN'), ('an', 'DT'), ('emergency', 'NN'), ('.', '.')]),
#  Tree('S', [('Once', 'RB'), ('they', 'PRP'), ('leave', 'VBP'), (',', ',')]),
#  Tree('S', [('the', 'DT'), ('bombs', 'NNS'), ('go', 'VB'), ('off', 'RB'), ('and', 'CC'), ('this', 'DT'), ('entire', 'JJ'), ('place', 'NN'), ('gets', 'VBZ'), ('buried', 'VBN'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ('kind', 'NN'), ('of', 'IN'), ('people', 'NNS'), ('are', 'VBP'), ('the', 'DT'), Tree('ORGANIZATION', [('VIPs', 'NNP')]), ('?', '.')]),
#  Tree('S', [('None', 'NN'), ('of', 'IN'), ('your', 'PRP$'), ('business', 'NN'), ('.', '.')]),
#  Tree('S', [('Number', 'NNP'), ('29', 'CD'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Emergency', 'NN')]), ('.', '.'), ('The', 'DT'), ('doc', 'NN'), ("'s", 'POS'), ('escaped', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Fuck', 'NNP')]), ('.', '.')]),
#  Tree('S', [('Damn', 'NN'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [('Why', 'WRB'), ('do', 'VBP'), ('you', 'PRP'), ('want', 'VB'), ('to', 'TO'), ('know', 'VB'), ('who', 'WP'), ('the', 'DT'), Tree('ORGANIZATION', [('VIPs', 'NNP')]), ('are', 'VBP'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('just', 'RB'), ('grateful', 'JJ'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('diving', 'NN'), ('gear', 'NN'), (',', ','), ('this', 'DT'), ('secret', 'JJ'), ('passage', 'NN'), (',', ',')]),
#  Tree('S', [('it', 'PRP'), ("'s", 'VBZ'), ('like', 'IN'), ('they', 'PRP'), ('prepared', 'VBD'), ('it', 'PRP'), ('all', 'DT'), ('for', 'IN'), ('us', 'PRP'), ('.', '.')]),
#  Tree('S', [('Not', 'RB'), ('only', 'RB'), ('are', 'VBP'), ('you', 'PRP'), ('more', 'RBR'), ('curious', 'JJ'), (',', ',')]),
#  Tree('S', [('your', 'PRP$'), ('voice', 'NN'), ('is', 'VBZ'), ('different', 'JJ'), ('too', 'RB'), ('.', '.')]),
#  Tree('S', [('Let', 'VB'), ('me', 'PRP'), ('see', 'VB'), ('your', 'PRP$'), ('face', 'NN'), ('.', '.')]),
#  Tree('S', [('Do', 'VBP'), ('you', 'PRP'), ('have', 'VB'), ('to', 'TO'), ('do', 'VB'), ('this', 'DT'), ('?', '.')]),
#  Tree('S', [('Should', 'MD'), ('I', 'PRP'), ('kill', 'VB'), ('you', 'PRP'), ('to', 'TO'), ('find', 'VB'), ('out', 'RP'), ('?', '.')]),
#  Tree('S', [('Who', 'WP'), ('are', 'VBP'), ('you', 'PRP'), ('?', '.')]),
#  Tree('S', [('Let', 'VB'), ('me', 'PRP'), ('see', 'VB'), ('your', 'PRP$'), ('face', 'NN'), ('.', '.')]),
#  Tree('S', [('Should', 'MD'), ('I', 'PRP'), ('kill', 'VB'), ('you', 'PRP'), ('to', 'TO'), ('find', 'VB'), ('out', 'RP'), ('?', '.')]),
#  Tree('S', [('Do', 'VBP'), ("n't", 'RB'), ('come', 'VB'), ('closer', 'JJR'), ('!', '.')]),
#  Tree('S', [Tree('GPE', [('Calm', 'NNP')]), ('down', 'RB'), ('.', '.'), ('We', 'PRP'), ('can', 'MD'), ('still', 'RB'), ('fix', 'VB'), ('this', 'DT'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Fix', 'NNP')]), ('this', 'DT'), ('how', 'WRB'), ('?', '.')]),
#  Tree('S', [('By', 'IN'), ('killing', 'VBG'), ('me', 'PRP'), ('?', '.')]),
#  Tree('S', [('Think', 'VBP'), ('about', 'IN'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [('Why', 'WRB'), ('would', 'MD'), ('I', 'PRP'), ('kill', 'VB'), ('you', 'PRP'), ('?', '.')]),
#  Tree('S', [('That', 'DT'), ("'ll", 'MD'), ('only', 'RB'), ('complicate', 'VB'), ('things', 'NNS'), ('.', '.')]),
#  Tree('S', [('Things', 'NNS'), ('are', 'VBP'), ('already', 'RB'), ('complicated', 'VBN'), ('.', '.')]),
#  Tree('S', [('Your', 'PRP$'), ('friend', 'NN'), ('is', 'VBZ'), ('dead', 'JJ'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('a', 'DT'), ('friend', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ('can', 'MD'), ('throw', 'VB'), ('his', 'PRP$'), ('body', 'NN'), ('into', 'IN'), ('the', 'DT'), ('incinerator', 'NN'), ('and', 'CC'), ('burn', 'VB'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('wo', 'MD'), ("n't", 'RB'), ('leave', 'VB'), ('a', 'DT'), ('trace', 'NN'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('huge', 'JJ'), ('problem', 'NN'), ('if', 'IN'), ('a', 'DT'), ('player', 'NN'), ('goes', 'VBZ'), ('missing', 'VBG'), (',', ',')]),
#  Tree('S', [('but', 'CC'), ('a', 'DT'), ('missing', 'JJ'), ('soldier', 'NN'), ('is', 'VBZ'), ('no', 'DT'), ('problem', 'NN'), ('at', 'IN'), ('all', 'DT'), ('.', '.')]),
#  Tree('S', [('Who', 'WP'), ('am', 'VBP'), ('I', 'PRP'), ('?', '.')]),
#  Tree('S', [('Who', 'WP'), ('I', 'PRP'), ('am', 'VBP'), ('is', 'VBZ'), ("n't", 'RB'), ('important', 'JJ'), ('.', '.')]),
#  Tree('S', [('What', 'WP'), ("'s", 'VBZ'), ('important', 'JJ'), ('is', 'VBZ'), ('the', 'DT'), ('identity', 'NN'), ('of', 'IN'), ('the', 'DT'), ('man', 'NN'), ('you', 'PRP'), ('did', 'VBD'), ('this', 'DT'), ('to', 'TO'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('man', 'NN'), ('you', 'PRP'), ('called', 'VBD'), ('a', 'DT'), ('zombie', 'NN'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('man', 'NN'), ('with', 'IN'), ('one', 'CD'), ('kidney', 'NN'), ('who', 'WP'), ('woke', 'VBD'), ('up', 'RP'), ('on', 'IN'), ('the', 'DT'), ('table', 'NN'), ('.', '.')]),
#  Tree('S', [('Do', 'VB'), ('you', 'PRP'), ('know', 'VB'), ('where', 'WRB'), ('his', 'PRP$'), ('other', 'JJ'), ('kidney', 'NN'), ('is', 'VBZ'), ('?', '.')]),
#  Tree('S', [('In', 'IN'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('in', 'IN'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('gave', 'VBD'), ('it', 'PRP'), ('to', 'TO'), ('me', 'PRP'), ('.', '.')]),
#  Tree('S', [('-That', 'DT'), ('man', 'NN'), ('is', 'VBZ'), ('my', 'PRP$'), ('brother', 'NN'), ('!', '.'), ('-No', 'NN'), ('!', '.')]),
#  Tree('S', [('It', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('woman', 'NN'), ('.', '.')]),
#  Tree('S', [('A', 'DT'), ('woman', 'NN'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('a', 'DT'), ('man', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'ll", 'MD'), ('make', 'VB'), ('sure', 'JJ'), ('I', 'PRP'), ('find', 'VBP'), ('out', 'RP'), ('what', 'WP'), ('the', 'DT'), ('next', 'JJ'), ('game', 'NN'), ('is', 'VBZ'), ('.', '.')]),
#  Tree('S', [('If', 'IN'), ('you', 'PRP'), ('make', 'VBP'), ('a', 'DT'), ('bigger', 'JJR'), ('scene', 'NN'), ('and', 'CC'), ('get', 'VB'), ('caught', 'VBN'), (',', ',')]),
#  Tree('S', [('we', 'PRP'), ("'ll", 'MD'), ('both', 'DT'), ('die', 'NNS'), ('like', 'IN'), ('dogs', 'NNS'), ('.', '.')]),
#  Tree('S', [('Trust', 'NNP'), ('me', 'PRP'), ('.', '.')]),
#  Tree('S', [('-We', 'NN'), ('still', 'RB'), ('have', 'VBP'), ('another', 'DT'), ('chance', 'NN'), ('.', '.'), ('-How', 'CC'), ('can', 'MD'), ('I', 'PRP'), ('trust', 'VB'), ('a', 'DT'), ('scumbag', 'NN'), ('like', 'IN'), ('you', 'PRP'), ('?', '.')]),
#  Tree('S', [('See', 'VB'), ('?', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('just', 'RB'), ('another', 'DT'), ('human', 'JJ'), ('like', 'IN'), ('you', 'PRP'), ('.', '.')]),
#  Tree('S', [('Yes', 'UH'), ('.', '.')]),
#  Tree('S', [('Just', 'RB'), ('go', 'VB'), ('back', 'RB'), ('in', 'IN'), ('silence', 'NN'), ('.', '.')]),
#  Tree('S', [('As', 'RB'), ('long', 'RB'), ('as', 'IN'), ('you', 'PRP'), ('return', 'VBP'), ('before', 'IN'), ('bedtime', 'NN'), ("'s", 'POS'), ('over', 'IN'), (',', ',')]),
#  Tree('S', [('we', 'PRP'), ('can', 'MD'), ('both', 'DT'), ('live', 'JJ'), ('.', '.')]),
#  Tree('S', [('Then', 'RB'), ('what', 'WP'), ('do', 'VBP'), ('I', 'PRP'), ('have', 'VB'), ('to', 'TO'), ('do', 'VB'), ('?', '.')]),
#  Tree('S', [Tree('GPE', [('Doctor', 'NN')]), ('.', '.')]),
#  Tree('S', [('Let', 'VB'), ("'s", 'POS'), ('get', 'VB'), ('you', 'PRP'), ('washed', 'VBN'), ('up', 'RP'), ('first', 'RB'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('telling', 'VBG'), ('the', 'DT'), ('truth', 'NN'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('was', 'VBD'), ('a', 'DT'), ('woman', 'NN'), ('.', '.')]),
#  Tree('S', [('How', 'WRB'), ('can', 'MD'), ('I', 'PRP'), ('believe', 'VB'), ('you', 'PRP'), ('?', '.')]),
#  Tree('S', [('Before', 'IN'), ('we', 'PRP'), ('opened', 'VBD'), ('her', 'PRP'), ('up', 'RP'), (',', ',')]),
#  Tree('S', [('we', 'PRP'), ('took', 'VBD'), ('turns', 'RP'), ('doing', 'VBG'), ('her', 'PRP'), ('.', '.')]),
#  Tree('S', [('We', 'PRP'), ('would', 'MD'), ("n't", 'RB'), ('have', 'VB'), ('done', 'VBN'), ('that', 'IN'), ('with', 'IN'), ('a', 'DT'), ('guy', 'NN'), ('.', '.')]),
#  Tree('S', [('If', 'IN'), ('you', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('believe', 'VB'), ('me', 'PRP'), (',', ','), ('check', 'VB'), ('the', 'DT'), ('list', 'NN'), ('.', '.')]),
#  Tree('S', [('-The', 'JJ'), ('list', 'NN'), ('?', '.'), ('-There', 'EX'), ("'s", 'VBZ'), ('a', 'DT'), ('list', 'NN'), ('of', 'IN'), ('all', 'PDT'), ('the', 'DT'), ('players', 'NNS'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ('has', 'VBZ'), ('all', 'DT'), ('their', 'PRP$'), ('personal', 'JJ'), ('information', 'NN'), ('.', '.')]),
#  Tree('S', [('-It', 'RB'), ('even', 'RB'), ('includes', 'VBZ'), ('their', 'PRP$'), ('medical', 'JJ'), ('records', 'NNS'), ('.', '.'), ('-Where', 'RB'), ('?', '.')]),
#  Tree('S', [('Above', 'IN'), ('the', 'DT'), ('ladderway', 'NN'), ('.', '.')]),
#  Tree('S', [('In', 'IN'), ('the', 'DT'), ('captain', 'NN'), ("'s", 'POS'), ('room', 'NN'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('captain', 'NN'), ('?', '.')]),
#  Tree('S', [('You', 'PRP'), ("'ve", 'VBP'), ('seen', 'VBN'), ('him', 'PRP'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('one', 'NN'), ('with', 'IN'), ('a', 'DT'), ('different', 'JJ'), ('mask', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'ll", 'MD'), ('help', 'VB'), ('you', 'PRP'), ('find', 'VB'), ('your', 'PRP$'), ('brother', 'NN'), ('.', '.')]),
#  Tree('S', [('And', 'CC'), ('I', 'PRP'), ("'ll", 'MD'), ('give', 'VB'), ('you', 'PRP'), ('all', 'PDT'), ('the', 'DT'), ('money', 'NN'), ('I', 'PRP'), ('got', 'VBD'), ('from', 'IN'), ('selling', 'VBG'), ('organs', 'NNS'), ('!', '.')]),
#  Tree('S', [('Once', 'RB'), ('we', 'PRP'), ('become', 'VBP'), ('a', 'DT'), ('team…', 'NN')]),
#  Tree('S', [('Whether', 'IN'), ('you', 'PRP'), ('sell', 'VBP'), ('off', 'RP'), ('organs', 'NNS'), ('from', 'IN'), ('the', 'DT'), ('dead', 'JJ'), ('or', 'CC'), ('devour', 'VB'), ('them', 'PRP'), (',', ',')]),
#  Tree('S', [('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('give', 'VB'), ('a', 'DT'), ('damn', 'NN'), ('.', '.')]),
#  Tree('S', [('However', 'RB'), (',', ',')]),
#  Tree('S', [('you', 'PRP'), ("'ve", 'VBP'), ('ruined', 'VBN'), ('the', 'DT'), ('most', 'RBS'), ('crucial', 'JJ'), ('element', 'NN'), ('of', 'IN'), ('this', 'DT'), ('place', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Equality', 'NN')]), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Everyone', 'NN')]), ('is', 'VBZ'), ('equal', 'JJ'), ('in', 'IN'), ('these', 'DT'), ('games', 'NNS'), ('.', '.')]),
#  Tree('S', [('Players', 'NNS'), ('compete', 'VBP'), ('in', 'IN'), ('a', 'DT'), ('fair', 'JJ'), ('game', 'NN'), ('under', 'IN'), ('the', 'DT'), ('same', 'JJ'), ('conditions', 'NNS'), ('.', '.')]),
#  Tree('S', [('These', 'DT'), ('people', 'NNS'), ('suffered', 'VBD'), ('from', 'IN'), ('inequality', 'NN'), ('and', 'CC'), ('discrimination', 'NN'), ('out', 'RB'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), (',', ',')]),
#  Tree('S', [('and', 'CC'), ('we', 'PRP'), ('offer', 'VBP'), ('them', 'PRP'), ('one', 'CD'), ('last', 'JJ'), ('chance', 'NN'), ('to', 'TO'), ('fight', 'VB'), ('on', 'IN'), ('equal', 'JJ'), ('footing', 'NN'), ('and', 'CC'), ('win', 'NN'), ('.', '.')]),
#  Tree('S', [('But', 'CC'), ('you', 'PRP'), ('have', 'VBP'), ('broken', 'VBN'), ('that', 'IN'), ('principle', 'NN'), ('.', '.')]),
#  Tree('S', [('I', 'PRP'), ("'m", 'VBP'), ('sorry', 'JJ'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Captain', 'NN')]), (',', ',')]),
#  Tree('S', [('we', 'PRP'), ('found', 'VBD'), ('another', 'DT'), ('one', 'CD'), ('.', '.')]),
#  Tree('S', [('It', 'PRP'), ("'s", 'VBZ'), ('number', 'NN'), ('28', 'CD'), ('.', '.')]),
#  Tree('S', [('There', 'EX'), ("'s", 'VBZ'), ('one', 'CD'), ('more', 'JJR'), (',', ',')]),
#  Tree('S', [('the', 'DT'), ('one', 'NN'), ('who', 'WP'), ('killed', 'VBD'), ('this', 'DT'), ('one', 'CD'), ('.', '.')]),
#  Tree('S', [('Maybe', 'RB'), ('he', 'PRP'), ('already', 'RB'), ('escaped', 'VBD'), ('into', 'IN'), ('the', 'DT'), ('sea', 'NN'), ('?', '.')]),
#  Tree('S', [('The', 'DT'), ('oxygen', 'NN'), ('tanks', 'NNS'), ('are', 'VBP'), ('all', 'DT'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ("'s", 'VBZ'), ('still', 'RB'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('Find', 'NNP'), ('him', 'PRP'), ('.', '.')]),
#  Tree('S', [('Number', 'NNP'), ('29', 'CD'), ('is', 'VBZ'), ('gone', 'VBN'), ('too', 'RB'), ('.', '.')]),
#  Tree('S', [('Find', 'NNP'), ('him', 'PRP'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ("'s", 'VBZ'), ('not', 'RB'), ('on', 'IN'), ('the', 'DT'), ('security', 'NN'), ('cameras', 'NN'), ('either', 'DT'), ('.', '.')]),
#  Tree('S', [('He', 'PRP'), ('has', 'VBZ'), ('to', 'TO'), ('be', 'VB'), ('in', 'IN'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('All', 'DT'), ('players', 'NNS'), (',', ','), ('please', 'NN'), ('line', 'NN'), ('up', 'RP'), ('immediately', 'RB'), ('in', 'IN'), ('the', 'DT'), ('center', 'NN'), ('.', '.')]),
#  Tree('S', [('Let', 'VB'), ('me', 'PRP'), ('repeat', 'VB'), ('.', '.')]),
#  Tree('S', [('-All', 'JJ'), ('players…', 'NN'), ('-Everyone', 'NN'), (',', ','), ('come', 'VB'), ('out', 'RP'), ('into', 'IN'), ('the', 'DT'), ('center', 'NN'), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Please', 'NNP')]), ('line', 'NN'), ('up', 'RP'), ('immediately', 'RB'), ('in', 'IN'), ('the', 'DT'), ('center', 'NN'), ('.', '.')]),
#  Tree('S', [('Move', 'NN'), ('it', 'PRP'), ('.', '.')]),
#  Tree('S', [('Damn', 'NN'), ('it', 'PRP'), ('.', '.'), ('What', 'WP'), ("'s", 'VBZ'), ('with', 'IN'), ('all', 'PDT'), ('the', 'DT'), ('fuss', 'NN'), ('again', 'RB'), ('?', '.')]),
#  Tree('S', [Tree('GPE', [('Boss', 'NNP')]), (',', ','), ('that', 'IN'), ('doctor…', 'NN')]),
#  Tree('S', [('Get', 'VB'), ('up', 'RP'), ('.', '.')]),
#  Tree('S', [('Get', 'VB'), ('up', 'RP'), ('.', '.')]),
#  Tree('S', [('Now', 'RB'), ('!', '.')]),
#  Tree('S', [('He', 'PRP'), ("'s", 'VBZ'), ('very', 'RB'), ('sick', 'JJ'), ('right', 'NN'), ('now', 'RB'), ('.', '.')]),
#  Tree('S', [('OCCUPATION', 'NN'), (':', ':'), ('CHAUFFEUR', 'NN')]),
#  Tree('S', [Tree('ORGANIZATION', [('LIST', 'NN'), ('OF', 'IN')]), Tree('ORGANIZATION', [('WINNERS', 'NNS')])]),
#  Tree('S', [Tree('PERSON', [('Hwang', 'NNP')]), ('In-ho', 'NNP'), ('.', '.')]),
#  Tree('S', [('The', 'DT'), ('year', 'NN'), ('2015…', 'CD')]),
#  Tree('S', [Tree('ORGANIZATION', [('LIST', 'NN')]), Tree('ORGANIZATION', [('OF', 'NNP')]), ('PLAYERS', 'NNP'), ('1', 'CD'), (',', ','), ('2015', 'CD')]),
#  Tree('S', [('Number', 'NNP'), ('132…', 'CD')]),
#  Tree('S', [Tree('GPE', [('Brother', 'NNP')]), ('.', '.')]),
#  Tree('S', [Tree('GPE', [('Subtitle', 'NNP')]), ('translation', 'NN'), ('by', 'IN'), (':', ':'), ('Eun-sook', 'JJ'), ('Yoon', 'NNP'), (',', ','), Tree('PERSON', [('Sharon', 'NNP'), ('Choi', 'NNP')])])]
